# %%
my_list_1=list('Севинчбек')
my_list_2=my_list_1.copy()

my_list_2.sort()

my_list_3=my_list_1+my_list_2
for i in range(0,3,1):
    my_list_3.pop(i-i)

print(my_list_1,'\n')
print(my_list_2,'\n')
print(my_list_3,'\n')
# Out:
# ['С', 'е', 'в', 'и', 'н', 'ч', 'б', 'е', 'к']
#
# ['С', 'б', 'в', 'е', 'е', 'и', 'к', 'н', 'ч']
#
# ['и', 'н', 'ч', 'б', 'е', 'к', 'С', 'б', 'в', 'е', 'е', 'и', 'к', 'н', 'ч']
