# %%
my_dict={2:3}
my_dict[1] = 10
my_dict['abc'] = 'def'
my_dict[0] = [0,1,2]
my_dict[(0,1)] = 'a'
my_dict[1] += 5
my_dict[0].append(3)
my_dict[0].remove(0)
for k, v in my_dict.items():
    if v == 'a': a=k
my_dict.pop(a)
print(my_dict)
# Out:
# {2: 3, 1: 15, 'abc': 'def', 0: [1, 2, 3]}
