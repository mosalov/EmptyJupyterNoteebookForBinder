# %%
# Загрузка зависимостей
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import keras
from keras.models import Sequential
from keras.layers import Dense
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from scipy import stats
from statsmodels.graphics.gofplots import qqplot
# Out:
# Using TensorFlow backend.

# %%
# Загрузка подготовленного набора данных
dataset = pd.read_csv('prepared_data.csv')
dataset.head(10)
# Out:
#         age  sex        cp  trestbps      chol  fbs   restecg   thalach  \
# 0  0.927622  1.0  1.000000  0.624287  0.410173  1.0  0.000000  0.090789
# 1 -2.117138  1.0  0.816497  0.454038  0.457160  0.0  0.707107  1.444548
# 2 -1.529863  0.0  0.577350  0.454038  0.321489  0.0  0.000000  0.931137
# 3  0.253797  1.0  0.577350  0.335019  0.418709  0.0  0.707107  1.141680
# 4  0.355054  0.0  0.000000  0.335019  0.689241  0.0  0.707107  0.601134
# 5  0.355054  1.0  0.000000  0.568560  0.281039  0.0  0.707107  0.008368
# 6  0.253797  0.0  0.577350  0.568560  0.565328  0.0  0.000000  0.212382
# 7 -1.125867  1.0  0.577350  0.335019  0.490983  0.0  0.707107  0.966733
# 8 -0.170168  1.0  0.816497  0.909866  0.304932  1.0  0.707107  0.563348
# 9  0.355054  1.0  0.816497  0.679061  0.191945  0.0  0.707107  1.002123
#
#    exang   oldpeak     slope   ca  num
# 0    0.0  0.552201  0.000000  0.0  1.0
# 1    0.0  0.715169  0.000000  0.0  1.0
# 2    0.0  0.398844  1.000000  0.0  1.0
# 3    0.0  0.265991  1.000000  0.0  1.0
# 4    1.0  0.210865  1.000000  0.0  1.0
# 5    0.0  0.145476  0.707107  0.0  1.0
# 6    0.0  0.379044  0.707107  0.0  1.0
# 7    0.0  0.314559  1.000000  0.0  1.0
# 8    0.0  0.179818  1.000000  0.0  1.0
# 9    0.0  0.436427  1.000000  0.0  1.0

# %%
X = dataset.drop(columns=['age']).values
Y = dataset['age'].values

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.3)

# %%
# Задаем параметры структуры нейронной сети.


input_layer_size = 12


first_hidden_layer_size = 10
second_hidden_layer_size = 10
third_hidden_layer_size = 40

output_layer_size = 1


epochs_number = 140
batch_size = 36

# %%
# Создание нейронной сети прямого распространения, пока она пустая, т.е. не содержит слоёв и нейронов.
model = Sequential()

# Входной слой и первый скрытый слой, функция активации - ReLU
model.add(Dense(first_hidden_layer_size, input_dim=input_layer_size, activation='relu'))

model.add(Dense(second_hidden_layer_size, activation='relu'))


model.add(Dense(output_layer_size, activation='linear'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 10)                130
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                110
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 251
# Trainable params: 251
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Настройка нейронной сети.
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error', 'mean_squared_error'])

# %%
# Обучение нейронной сети.
history = model.fit(X_train, Y_train, validation_data = (X_test,Y_test), epochs=epochs_number, batch_size=batch_size)
# Out:
# Train on 212 samples, validate on 91 samples
# Epoch 1/140
# 212/212 [==============================] - 0s 2ms/step - loss: 1.0408 - mean_absolute_error: 0.8229 - mean_squared_error: 1.0408 - val_loss: 0.9815 - val_mean_absolute_error: 0.7844 - val_mean_squared_error: 0.9815
# Epoch 2/140
# 212/212 [==============================] - 0s 121us/step - loss: 1.0202 - mean_absolute_error: 0.8182 - mean_squared_error: 1.0202 - val_loss: 0.9626 - val_mean_absolute_error: 0.7776 - val_mean_squared_error: 0.9626
# Epoch 3/140
# 212/212 [==============================] - 0s 139us/step - loss: 1.0007 - mean_absolute_error: 0.8125 - mean_squared_error: 1.0007 - val_loss: 0.9477 - val_mean_absolute_error: 0.7719 - val_mean_squared_error: 0.9477
# Epoch 4/140
# 212/212 [==============================] - 0s 126us/step - loss: 0.9845 - mean_absolute_error: 0.8092 - mean_squared_error: 0.9845 - val_loss: 0.9345 - val_mean_absolute_error: 0.7659 - val_mean_squared_error: 0.9345
# Epoch 5/140
# 212/212 [==============================] - 0s 342us/step - loss: 0.9677 - mean_absolute_error: 0.8042 - mean_squared_error: 0.9677 - val_loss: 0.9228 - val_mean_absolute_error: 0.7604 - val_mean_squared_error: 0.9228
# Epoch 6/140
# 212/212 [==============================] - 0s 93us/step - loss: 0.9556 - mean_absolute_error: 0.8010 - mean_squared_error: 0.9556 - val_loss: 0.9107 - val_mean_absolute_error: 0.7556 - val_mean_squared_error: 0.9107
# Epoch 7/140
# 212/212 [==============================] - 0s 226us/step - loss: 0.9464 - mean_absolute_error: 0.7990 - mean_squared_error: 0.9464 - val_loss: 0.8995 - val_mean_absolute_error: 0.7516 - val_mean_squared_error: 0.8995
# Epoch 8/140
# 212/212 [==============================] - 0s 148us/step - loss: 0.9345 - mean_absolute_error: 0.7953 - mean_squared_error: 0.9345 - val_loss: 0.8896 - val_mean_absolute_error: 0.7477 - val_mean_squared_error: 0.8896
# Epoch 9/140
# 212/212 [==============================] - 0s 103us/step - loss: 0.9250 - mean_absolute_error: 0.7920 - mean_squared_error: 0.9250 - val_loss: 0.8810 - val_mean_absolute_error: 0.7439 - val_mean_squared_error: 0.8810
# Epoch 10/140
# 212/212 [==============================] - 0s 270us/step - loss: 0.9165 - mean_absolute_error: 0.7886 - mean_squared_error: 0.9165 - val_loss: 0.8730 - val_mean_absolute_error: 0.7405 - val_mean_squared_error: 0.8730
# Epoch 11/140
# 212/212 [==============================] - 0s 103us/step - loss: 0.9082 - mean_absolute_error: 0.7853 - mean_squared_error: 0.9082 - val_loss: 0.8656 - val_mean_absolute_error: 0.7374 - val_mean_squared_error: 0.8656
# Epoch 12/140
# 212/212 [==============================] - 0s 86us/step - loss: 0.9003 - mean_absolute_error: 0.7815 - mean_squared_error: 0.9003 - val_loss: 0.8592 - val_mean_absolute_error: 0.7341 - val_mean_squared_error: 0.8592
# Epoch 13/140
# 212/212 [==============================] - 0s 184us/step - loss: 0.8915 - mean_absolute_error: 0.7773 - mean_squared_error: 0.8915 - val_loss: 0.8529 - val_mean_absolute_error: 0.7311 - val_mean_squared_error: 0.8529
# Epoch 14/140
# 212/212 [==============================] - 0s 65us/step - loss: 0.8842 - mean_absolute_error: 0.7734 - mean_squared_error: 0.8842 - val_loss: 0.8457 - val_mean_absolute_error: 0.7275 - val_mean_squared_error: 0.8457
# Epoch 15/140
# 212/212 [==============================] - 0s 85us/step - loss: 0.8761 - mean_absolute_error: 0.7687 - mean_squared_error: 0.8761 - val_loss: 0.8381 - val_mean_absolute_error: 0.7234 - val_mean_squared_error: 0.8381
# Epoch 16/140
# 212/212 [==============================] - 0s 63us/step - loss: 0.8686 - mean_absolute_error: 0.7646 - mean_squared_error: 0.8686 - val_loss: 0.8292 - val_mean_absolute_error: 0.7193 - val_mean_squared_error: 0.8292
# Epoch 17/140
# 212/212 [==============================] - 0s 69us/step - loss: 0.8588 - mean_absolute_error: 0.7593 - mean_squared_error: 0.8588 - val_loss: 0.8209 - val_mean_absolute_error: 0.7156 - val_mean_squared_error: 0.8209
# Epoch 18/140
# 212/212 [==============================] - 0s 54us/step - loss: 0.8507 - mean_absolute_error: 0.7551 - mean_squared_error: 0.8507 - val_loss: 0.8136 - val_mean_absolute_error: 0.7117 - val_mean_squared_error: 0.8136
# Epoch 19/140
# 212/212 [==============================] - 0s 56us/step - loss: 0.8429 - mean_absolute_error: 0.7506 - mean_squared_error: 0.8429 - val_loss: 0.8054 - val_mean_absolute_error: 0.7080 - val_mean_squared_error: 0.8054
# Epoch 20/140
# 212/212 [==============================] - 0s 63us/step - loss: 0.8358 - mean_absolute_error: 0.7465 - mean_squared_error: 0.8358 - val_loss: 0.7983 - val_mean_absolute_error: 0.7046 - val_mean_squared_error: 0.7983
# Epoch 21/140
# 212/212 [==============================] - 0s 237us/step - loss: 0.8298 - mean_absolute_error: 0.7437 - mean_squared_error: 0.8298 - val_loss: 0.7898 - val_mean_absolute_error: 0.7010 - val_mean_squared_error: 0.7898
# Epoch 22/140
# 212/212 [==============================] - 0s 70us/step - loss: 0.8213 - mean_absolute_error: 0.7396 - mean_squared_error: 0.8213 - val_loss: 0.7828 - val_mean_absolute_error: 0.6977 - val_mean_squared_error: 0.7828
# Epoch 23/140
# 212/212 [==============================] - 0s 56us/step - loss: 0.8137 - mean_absolute_error: 0.7355 - mean_squared_error: 0.8137 - val_loss: 0.7780 - val_mean_absolute_error: 0.6947 - val_mean_squared_error: 0.7780
# Epoch 24/140
# 212/212 [==============================] - 0s 68us/step - loss: 0.8069 - mean_absolute_error: 0.7315 - mean_squared_error: 0.8069 - val_loss: 0.7720 - val_mean_absolute_error: 0.6913 - val_mean_squared_error: 0.7720
# Epoch 25/140
# 212/212 [==============================] - 0s 221us/step - loss: 0.8009 - mean_absolute_error: 0.7278 - mean_squared_error: 0.8009 - val_loss: 0.7669 - val_mean_absolute_error: 0.6880 - val_mean_squared_error: 0.7669
# Epoch 26/140
# 212/212 [==============================] - 0s 52us/step - loss: 0.7948 - mean_absolute_error: 0.7242 - mean_squared_error: 0.7948 - val_loss: 0.7594 - val_mean_absolute_error: 0.6845 - val_mean_squared_error: 0.7594
# Epoch 27/140
# 212/212 [==============================] - 0s 59us/step - loss: 0.7875 - mean_absolute_error: 0.7212 - mean_squared_error: 0.7875 - val_loss: 0.7540 - val_mean_absolute_error: 0.6816 - val_mean_squared_error: 0.7540
# Epoch 28/140
# 212/212 [==============================] - 0s 57us/step - loss: 0.7812 - mean_absolute_error: 0.7180 - mean_squared_error: 0.7812 - val_loss: 0.7491 - val_mean_absolute_error: 0.6787 - val_mean_squared_error: 0.7491
# Epoch 29/140
# 212/212 [==============================] - 0s 230us/step - loss: 0.7750 - mean_absolute_error: 0.7149 - mean_squared_error: 0.7750 - val_loss: 0.7439 - val_mean_absolute_error: 0.6766 - val_mean_squared_error: 0.7439
# Epoch 30/140
# 212/212 [==============================] - 0s 65us/step - loss: 0.7695 - mean_absolute_error: 0.7124 - mean_squared_error: 0.7695 - val_loss: 0.7384 - val_mean_absolute_error: 0.6748 - val_mean_squared_error: 0.7384
# Epoch 31/140
# 212/212 [==============================] - 0s 62us/step - loss: 0.7630 - mean_absolute_error: 0.7096 - mean_squared_error: 0.7630 - val_loss: 0.7350 - val_mean_absolute_error: 0.6730 - val_mean_squared_error: 0.7350
# Epoch 32/140
# 212/212 [==============================] - 0s 62us/step - loss: 0.7573 - mean_absolute_error: 0.7070 - mean_squared_error: 0.7573 - val_loss: 0.7305 - val_mean_absolute_error: 0.6714 - val_mean_squared_error: 0.7305
# Epoch 33/140
# 212/212 [==============================] - 0s 55us/step - loss: 0.7497 - mean_absolute_error: 0.7036 - mean_squared_error: 0.7497 - val_loss: 0.7280 - val_mean_absolute_error: 0.6701 - val_mean_squared_error: 0.7280
# Epoch 34/140
# 212/212 [==============================] - 0s 69us/step - loss: 0.7441 - mean_absolute_error: 0.7007 - mean_squared_error: 0.7441 - val_loss: 0.7232 - val_mean_absolute_error: 0.6688 - val_mean_squared_error: 0.7232
# Epoch 35/140
# 212/212 [==============================] - 0s 57us/step - loss: 0.7395 - mean_absolute_error: 0.6981 - mean_squared_error: 0.7395 - val_loss: 0.7205 - val_mean_absolute_error: 0.6664 - val_mean_squared_error: 0.7205
# Epoch 36/140
# 212/212 [==============================] - 0s 57us/step - loss: 0.7353 - mean_absolute_error: 0.6956 - mean_squared_error: 0.7353 - val_loss: 0.7159 - val_mean_absolute_error: 0.6637 - val_mean_squared_error: 0.7159
# Epoch 37/140
# 212/212 [==============================] - 0s 58us/step - loss: 0.7283 - mean_absolute_error: 0.6919 - mean_squared_error: 0.7283 - val_loss: 0.7110 - val_mean_absolute_error: 0.6620 - val_mean_squared_error: 0.7110
# Epoch 38/140
# 212/212 [==============================] - 0s 256us/step - loss: 0.7235 - mean_absolute_error: 0.6901 - mean_squared_error: 0.7235 - val_loss: 0.7048 - val_mean_absolute_error: 0.6604 - val_mean_squared_error: 0.7048
# Epoch 39/140
# 212/212 [==============================] - 0s 71us/step - loss: 0.7189 - mean_absolute_error: 0.6879 - mean_squared_error: 0.7189 - val_loss: 0.7020 - val_mean_absolute_error: 0.6585 - val_mean_squared_error: 0.7020
# Epoch 40/140
# 212/212 [==============================] - 0s 63us/step - loss: 0.7131 - mean_absolute_error: 0.6847 - mean_squared_error: 0.7131 - val_loss: 0.6979 - val_mean_absolute_error: 0.6564 - val_mean_squared_error: 0.6979
# Epoch 41/140
# 212/212 [==============================] - 0s 50us/step - loss: 0.7087 - mean_absolute_error: 0.6821 - mean_squared_error: 0.7087 - val_loss: 0.6923 - val_mean_absolute_error: 0.6545 - val_mean_squared_error: 0.6923
# Epoch 42/140
# 212/212 [==============================] - 0s 236us/step - loss: 0.7041 - mean_absolute_error: 0.6803 - mean_squared_error: 0.7041 - val_loss: 0.6887 - val_mean_absolute_error: 0.6524 - val_mean_squared_error: 0.6887
# Epoch 43/140
# 212/212 [==============================] - 0s 70us/step - loss: 0.7005 - mean_absolute_error: 0.6780 - mean_squared_error: 0.7005 - val_loss: 0.6831 - val_mean_absolute_error: 0.6504 - val_mean_squared_error: 0.6831
# Epoch 44/140
# 212/212 [==============================] - 0s 59us/step - loss: 0.6960 - mean_absolute_error: 0.6756 - mean_squared_error: 0.6960 - val_loss: 0.6793 - val_mean_absolute_error: 0.6481 - val_mean_squared_error: 0.6793
# Epoch 45/140
# 212/212 [==============================] - 0s 67us/step - loss: 0.6933 - mean_absolute_error: 0.6739 - mean_squared_error: 0.6933 - val_loss: 0.6773 - val_mean_absolute_error: 0.6453 - val_mean_squared_error: 0.6773
# Epoch 46/140
# 212/212 [==============================] - 0s 205us/step - loss: 0.6890 - mean_absolute_error: 0.6715 - mean_squared_error: 0.6890 - val_loss: 0.6738 - val_mean_absolute_error: 0.6430 - val_mean_squared_error: 0.6738
# Epoch 47/140
# 212/212 [==============================] - 0s 53us/step - loss: 0.6860 - mean_absolute_error: 0.6699 - mean_squared_error: 0.6860 - val_loss: 0.6707 - val_mean_absolute_error: 0.6405 - val_mean_squared_error: 0.6707
# Epoch 48/140
# 212/212 [==============================] - 0s 53us/step - loss: 0.6813 - mean_absolute_error: 0.6678 - mean_squared_error: 0.6813 - val_loss: 0.6651 - val_mean_absolute_error: 0.6387 - val_mean_squared_error: 0.6651
# Epoch 49/140
# 212/212 [==============================] - 0s 55us/step - loss: 0.6786 - mean_absolute_error: 0.6661 - mean_squared_error: 0.6786 - val_loss: 0.6619 - val_mean_absolute_error: 0.6367 - val_mean_squared_error: 0.6619
# Epoch 50/140
# 212/212 [==============================] - 0s 71us/step - loss: 0.6758 - mean_absolute_error: 0.6647 - mean_squared_error: 0.6758 - val_loss: 0.6578 - val_mean_absolute_error: 0.6347 - val_mean_squared_error: 0.6578
# Epoch 51/140
# 212/212 [==============================] - 0s 61us/step - loss: 0.6727 - mean_absolute_error: 0.6626 - mean_squared_error: 0.6727 - val_loss: 0.6542 - val_mean_absolute_error: 0.6331 - val_mean_squared_error: 0.6542
# Epoch 52/140
# 212/212 [==============================] - 0s 56us/step - loss: 0.6696 - mean_absolute_error: 0.6607 - mean_squared_error: 0.6696 - val_loss: 0.6523 - val_mean_absolute_error: 0.6307 - val_mean_squared_error: 0.6523
# Epoch 53/140
# 212/212 [==============================] - 0s 58us/step - loss: 0.6676 - mean_absolute_error: 0.6600 - mean_squared_error: 0.6676 - val_loss: 0.6507 - val_mean_absolute_error: 0.6285 - val_mean_squared_error: 0.6507
# Epoch 54/140
# 212/212 [==============================] - 0s 53us/step - loss: 0.6655 - mean_absolute_error: 0.6591 - mean_squared_error: 0.6655 - val_loss: 0.6482 - val_mean_absolute_error: 0.6263 - val_mean_squared_error: 0.6482
# Epoch 55/140
# 212/212 [==============================] - 0s 54us/step - loss: 0.6631 - mean_absolute_error: 0.6576 - mean_squared_error: 0.6631 - val_loss: 0.6439 - val_mean_absolute_error: 0.6253 - val_mean_squared_error: 0.6439
# Epoch 56/140
# 212/212 [==============================] - 0s 60us/step - loss: 0.6598 - mean_absolute_error: 0.6561 - mean_squared_error: 0.6598 - val_loss: 0.6415 - val_mean_absolute_error: 0.6234 - val_mean_squared_error: 0.6415
# Epoch 57/140
# 212/212 [==============================] - 0s 66us/step - loss: 0.6582 - mean_absolute_error: 0.6556 - mean_squared_error: 0.6582 - val_loss: 0.6387 - val_mean_absolute_error: 0.6215 - val_mean_squared_error: 0.6387
# Epoch 58/140
# 212/212 [==============================] - 0s 59us/step - loss: 0.6555 - mean_absolute_error: 0.6542 - mean_squared_error: 0.6555 - val_loss: 0.6368 - val_mean_absolute_error: 0.6191 - val_mean_squared_error: 0.6368
# Epoch 59/140
# 212/212 [==============================] - 0s 53us/step - loss: 0.6538 - mean_absolute_error: 0.6535 - mean_squared_error: 0.6538 - val_loss: 0.6341 - val_mean_absolute_error: 0.6179 - val_mean_squared_error: 0.6341
# Epoch 60/140
# 212/212 [==============================] - 0s 217us/step - loss: 0.6515 - mean_absolute_error: 0.6523 - mean_squared_error: 0.6515 - val_loss: 0.6332 - val_mean_absolute_error: 0.6160 - val_mean_squared_error: 0.6332
# Epoch 61/140
# 212/212 [==============================] - 0s 59us/step - loss: 0.6509 - mean_absolute_error: 0.6522 - mean_squared_error: 0.6509 - val_loss: 0.6299 - val_mean_absolute_error: 0.6149 - val_mean_squared_error: 0.6299
# Epoch 62/140
# 212/212 [==============================] - 0s 72us/step - loss: 0.6508 - mean_absolute_error: 0.6517 - mean_squared_error: 0.6508 - val_loss: 0.6261 - val_mean_absolute_error: 0.6149 - val_mean_squared_error: 0.6261
# Epoch 63/140
# 212/212 [==============================] - 0s 56us/step - loss: 0.6469 - mean_absolute_error: 0.6503 - mean_squared_error: 0.6469 - val_loss: 0.6261 - val_mean_absolute_error: 0.6128 - val_mean_squared_error: 0.6261
# Epoch 64/140
# 212/212 [==============================] - 0s 203us/step - loss: 0.6444 - mean_absolute_error: 0.6488 - mean_squared_error: 0.6444 - val_loss: 0.6237 - val_mean_absolute_error: 0.6121 - val_mean_squared_error: 0.6237
# Epoch 65/140
# 212/212 [==============================] - 0s 85us/step - loss: 0.6435 - mean_absolute_error: 0.6477 - mean_squared_error: 0.6435 - val_loss: 0.6207 - val_mean_absolute_error: 0.6120 - val_mean_squared_error: 0.6207
# Epoch 66/140
# 212/212 [==============================] - 0s 61us/step - loss: 0.6420 - mean_absolute_error: 0.6469 - mean_squared_error: 0.6420 - val_loss: 0.6212 - val_mean_absolute_error: 0.6098 - val_mean_squared_error: 0.6212
# Epoch 67/140
# 212/212 [==============================] - 0s 60us/step - loss: 0.6393 - mean_absolute_error: 0.6462 - mean_squared_error: 0.6393 - val_loss: 0.6184 - val_mean_absolute_error: 0.6089 - val_mean_squared_error: 0.6184
# Epoch 68/140
# 212/212 [==============================] - 0s 60us/step - loss: 0.6384 - mean_absolute_error: 0.6456 - mean_squared_error: 0.6384 - val_loss: 0.6177 - val_mean_absolute_error: 0.6078 - val_mean_squared_error: 0.6177
# Epoch 69/140
# 212/212 [==============================] - 0s 219us/step - loss: 0.6362 - mean_absolute_error: 0.6448 - mean_squared_error: 0.6362 - val_loss: 0.6157 - val_mean_absolute_error: 0.6071 - val_mean_squared_error: 0.6157
# Epoch 70/140
# 212/212 [==============================] - 0s 76us/step - loss: 0.6363 - mean_absolute_error: 0.6444 - mean_squared_error: 0.6363 - val_loss: 0.6129 - val_mean_absolute_error: 0.6079 - val_mean_squared_error: 0.6129
# Epoch 71/140
# 212/212 [==============================] - 0s 67us/step - loss: 0.6333 - mean_absolute_error: 0.6434 - mean_squared_error: 0.6333 - val_loss: 0.6122 - val_mean_absolute_error: 0.6059 - val_mean_squared_error: 0.6122
# Epoch 72/140
# 212/212 [==============================] - 0s 56us/step - loss: 0.6316 - mean_absolute_error: 0.6428 - mean_squared_error: 0.6316 - val_loss: 0.6125 - val_mean_absolute_error: 0.6046 - val_mean_squared_error: 0.6125
# Epoch 73/140
# 212/212 [==============================] - 0s 165us/step - loss: 0.6305 - mean_absolute_error: 0.6420 - mean_squared_error: 0.6305 - val_loss: 0.6109 - val_mean_absolute_error: 0.6039 - val_mean_squared_error: 0.6109
# Epoch 74/140
# 212/212 [==============================] - 0s 65us/step - loss: 0.6291 - mean_absolute_error: 0.6412 - mean_squared_error: 0.6291 - val_loss: 0.6084 - val_mean_absolute_error: 0.6031 - val_mean_squared_error: 0.6084
# Epoch 75/140
# 212/212 [==============================] - 0s 58us/step - loss: 0.6275 - mean_absolute_error: 0.6406 - mean_squared_error: 0.6275 - val_loss: 0.6072 - val_mean_absolute_error: 0.6020 - val_mean_squared_error: 0.6072
# Epoch 76/140
# 212/212 [==============================] - 0s 54us/step - loss: 0.6264 - mean_absolute_error: 0.6400 - mean_squared_error: 0.6264 - val_loss: 0.6059 - val_mean_absolute_error: 0.6010 - val_mean_squared_error: 0.6059
# Epoch 77/140
# 212/212 [==============================] - 0s 66us/step - loss: 0.6248 - mean_absolute_error: 0.6397 - mean_squared_error: 0.6248 - val_loss: 0.6041 - val_mean_absolute_error: 0.6009 - val_mean_squared_error: 0.6041
# Epoch 78/140
# 212/212 [==============================] - 0s 76us/step - loss: 0.6244 - mean_absolute_error: 0.6395 - mean_squared_error: 0.6244 - val_loss: 0.6026 - val_mean_absolute_error: 0.6004 - val_mean_squared_error: 0.6026
# Epoch 79/140
# 212/212 [==============================] - 0s 60us/step - loss: 0.6221 - mean_absolute_error: 0.6387 - mean_squared_error: 0.6221 - val_loss: 0.6020 - val_mean_absolute_error: 0.5992 - val_mean_squared_error: 0.6020
# Epoch 80/140
# 212/212 [==============================] - 0s 68us/step - loss: 0.6207 - mean_absolute_error: 0.6377 - mean_squared_error: 0.6207 - val_loss: 0.6014 - val_mean_absolute_error: 0.5987 - val_mean_squared_error: 0.6014
# Epoch 81/140
# 212/212 [==============================] - 0s 227us/step - loss: 0.6198 - mean_absolute_error: 0.6374 - mean_squared_error: 0.6198 - val_loss: 0.6005 - val_mean_absolute_error: 0.5980 - val_mean_squared_error: 0.6005
# Epoch 82/140
# 212/212 [==============================] - 0s 64us/step - loss: 0.6192 - mean_absolute_error: 0.6372 - mean_squared_error: 0.6192 - val_loss: 0.5998 - val_mean_absolute_error: 0.5977 - val_mean_squared_error: 0.5998
# Epoch 83/140
# 212/212 [==============================] - 0s 61us/step - loss: 0.6175 - mean_absolute_error: 0.6363 - mean_squared_error: 0.6175 - val_loss: 0.5990 - val_mean_absolute_error: 0.5972 - val_mean_squared_error: 0.5990
# Epoch 84/140
# 212/212 [==============================] - 0s 56us/step - loss: 0.6168 - mean_absolute_error: 0.6359 - mean_squared_error: 0.6168 - val_loss: 0.5980 - val_mean_absolute_error: 0.5968 - val_mean_squared_error: 0.5980
# Epoch 85/140
# 212/212 [==============================] - 0s 49us/step - loss: 0.6164 - mean_absolute_error: 0.6359 - mean_squared_error: 0.6164 - val_loss: 0.5968 - val_mean_absolute_error: 0.5970 - val_mean_squared_error: 0.5968
# Epoch 86/140
# 212/212 [==============================] - 0s 235us/step - loss: 0.6148 - mean_absolute_error: 0.6348 - mean_squared_error: 0.6148 - val_loss: 0.5963 - val_mean_absolute_error: 0.5964 - val_mean_squared_error: 0.5963
# Epoch 87/140
# 212/212 [==============================] - 0s 56us/step - loss: 0.6135 - mean_absolute_error: 0.6341 - mean_squared_error: 0.6135 - val_loss: 0.5961 - val_mean_absolute_error: 0.5952 - val_mean_squared_error: 0.5961
# Epoch 88/140
# 212/212 [==============================] - 0s 63us/step - loss: 0.6130 - mean_absolute_error: 0.6333 - mean_squared_error: 0.6130 - val_loss: 0.5968 - val_mean_absolute_error: 0.5948 - val_mean_squared_error: 0.5968
# Epoch 89/140
# 212/212 [==============================] - 0s 75us/step - loss: 0.6126 - mean_absolute_error: 0.6336 - mean_squared_error: 0.6126 - val_loss: 0.5950 - val_mean_absolute_error: 0.5947 - val_mean_squared_error: 0.5950
# Epoch 90/140
# 212/212 [==============================] - 0s 61us/step - loss: 0.6111 - mean_absolute_error: 0.6330 - mean_squared_error: 0.6111 - val_loss: 0.5944 - val_mean_absolute_error: 0.5946 - val_mean_squared_error: 0.5944
# Epoch 91/140
# 212/212 [==============================] - 0s 83us/step - loss: 0.6107 - mean_absolute_error: 0.6329 - mean_squared_error: 0.6107 - val_loss: 0.5936 - val_mean_absolute_error: 0.5943 - val_mean_squared_error: 0.5936
# Epoch 92/140
# 212/212 [==============================] - ETA: 0s - loss: 0.7030 - mean_absolute_error: 0.6581 - mean_squared_error: 0.70 - 0s 49us/step - loss: 0.6114 - mean_absolute_error: 0.6335 - mean_squared_error: 0.6114 - val_loss: 0.5948 - val_mean_absolute_error: 0.5936 - val_mean_squared_error: 0.5948
# Epoch 93/140
# 212/212 [==============================] - 0s 48us/step - loss: 0.6100 - mean_absolute_error: 0.6321 - mean_squared_error: 0.6100 - val_loss: 0.5931 - val_mean_absolute_error: 0.5937 - val_mean_squared_error: 0.5931
# Epoch 94/140
# 212/212 [==============================] - 0s 58us/step - loss: 0.6076 - mean_absolute_error: 0.6308 - mean_squared_error: 0.6076 - val_loss: 0.5928 - val_mean_absolute_error: 0.5929 - val_mean_squared_error: 0.5928
# Epoch 95/140
# 212/212 [==============================] - 0s 194us/step - loss: 0.6065 - mean_absolute_error: 0.6304 - mean_squared_error: 0.6065 - val_loss: 0.5931 - val_mean_absolute_error: 0.5925 - val_mean_squared_error: 0.5931
# Epoch 96/140
# 212/212 [==============================] - 0s 55us/step - loss: 0.6059 - mean_absolute_error: 0.6300 - mean_squared_error: 0.6059 - val_loss: 0.5924 - val_mean_absolute_error: 0.5924 - val_mean_squared_error: 0.5924
# Epoch 97/140
# 212/212 [==============================] - 0s 64us/step - loss: 0.6048 - mean_absolute_error: 0.6293 - mean_squared_error: 0.6048 - val_loss: 0.5918 - val_mean_absolute_error: 0.5921 - val_mean_squared_error: 0.5918
# Epoch 98/140
# 212/212 [==============================] - 0s 53us/step - loss: 0.6042 - mean_absolute_error: 0.6291 - mean_squared_error: 0.6042 - val_loss: 0.5919 - val_mean_absolute_error: 0.5919 - val_mean_squared_error: 0.5919
# Epoch 99/140
# 212/212 [==============================] - 0s 51us/step - loss: 0.6043 - mean_absolute_error: 0.6291 - mean_squared_error: 0.6043 - val_loss: 0.5926 - val_mean_absolute_error: 0.5913 - val_mean_squared_error: 0.5926
# Epoch 100/140
# 212/212 [==============================] - 0s 233us/step - loss: 0.6031 - mean_absolute_error: 0.6280 - mean_squared_error: 0.6031 - val_loss: 0.5923 - val_mean_absolute_error: 0.5912 - val_mean_squared_error: 0.5923
# Epoch 101/140
# 212/212 [==============================] - 0s 53us/step - loss: 0.6012 - mean_absolute_error: 0.6270 - mean_squared_error: 0.6012 - val_loss: 0.5909 - val_mean_absolute_error: 0.5913 - val_mean_squared_error: 0.5909
# Epoch 102/140
# 212/212 [==============================] - 0s 51us/step - loss: 0.6008 - mean_absolute_error: 0.6266 - mean_squared_error: 0.6008 - val_loss: 0.5902 - val_mean_absolute_error: 0.5916 - val_mean_squared_error: 0.5902
# Epoch 103/140
# 212/212 [==============================] - 0s 61us/step - loss: 0.6009 - mean_absolute_error: 0.6268 - mean_squared_error: 0.6009 - val_loss: 0.5895 - val_mean_absolute_error: 0.5916 - val_mean_squared_error: 0.5895
# Epoch 104/140
# 212/212 [==============================] - 0s 68us/step - loss: 0.5993 - mean_absolute_error: 0.6257 - mean_squared_error: 0.5993 - val_loss: 0.5897 - val_mean_absolute_error: 0.5904 - val_mean_squared_error: 0.5897
# Epoch 105/140
# 212/212 [==============================] - 0s 209us/step - loss: 0.5984 - mean_absolute_error: 0.6255 - mean_squared_error: 0.5984 - val_loss: 0.5906 - val_mean_absolute_error: 0.5896 - val_mean_squared_error: 0.5906
# Epoch 106/140
# 212/212 [==============================] - 0s 59us/step - loss: 0.5983 - mean_absolute_error: 0.6252 - mean_squared_error: 0.5983 - val_loss: 0.5910 - val_mean_absolute_error: 0.5894 - val_mean_squared_error: 0.5910
# Epoch 107/140
# 212/212 [==============================] - 0s 74us/step - loss: 0.5972 - mean_absolute_error: 0.6248 - mean_squared_error: 0.5972 - val_loss: 0.5904 - val_mean_absolute_error: 0.5893 - val_mean_squared_error: 0.5904
# Epoch 108/140
# 212/212 [==============================] - 0s 58us/step - loss: 0.5964 - mean_absolute_error: 0.6238 - mean_squared_error: 0.5964 - val_loss: 0.5894 - val_mean_absolute_error: 0.5901 - val_mean_squared_error: 0.5894
# Epoch 109/140
# 212/212 [==============================] - 0s 228us/step - loss: 0.5958 - mean_absolute_error: 0.6239 - mean_squared_error: 0.5958 - val_loss: 0.5893 - val_mean_absolute_error: 0.5898 - val_mean_squared_error: 0.5893
# Epoch 110/140
# 212/212 [==============================] - 0s 71us/step - loss: 0.5952 - mean_absolute_error: 0.6234 - mean_squared_error: 0.5952 - val_loss: 0.5901 - val_mean_absolute_error: 0.5887 - val_mean_squared_error: 0.5901
# Epoch 111/140
# 212/212 [==============================] - 0s 69us/step - loss: 0.5943 - mean_absolute_error: 0.6230 - mean_squared_error: 0.5943 - val_loss: 0.5895 - val_mean_absolute_error: 0.5891 - val_mean_squared_error: 0.5895
# Epoch 112/140
# 212/212 [==============================] - 0s 246us/step - loss: 0.5934 - mean_absolute_error: 0.6223 - mean_squared_error: 0.5934 - val_loss: 0.5897 - val_mean_absolute_error: 0.5890 - val_mean_squared_error: 0.5897
# Epoch 113/140
# 212/212 [==============================] - 0s 71us/step - loss: 0.5930 - mean_absolute_error: 0.6221 - mean_squared_error: 0.5930 - val_loss: 0.5894 - val_mean_absolute_error: 0.5889 - val_mean_squared_error: 0.5894
# Epoch 114/140
# 212/212 [==============================] - 0s 68us/step - loss: 0.5944 - mean_absolute_error: 0.6226 - mean_squared_error: 0.5944 - val_loss: 0.5891 - val_mean_absolute_error: 0.5896 - val_mean_squared_error: 0.5891
# Epoch 115/140
# 212/212 [==============================] - 0s 59us/step - loss: 0.5919 - mean_absolute_error: 0.6209 - mean_squared_error: 0.5919 - val_loss: 0.5907 - val_mean_absolute_error: 0.5885 - val_mean_squared_error: 0.5907
# Epoch 116/140
# 212/212 [==============================] - 0s 243us/step - loss: 0.5914 - mean_absolute_error: 0.6209 - mean_squared_error: 0.5914 - val_loss: 0.5909 - val_mean_absolute_error: 0.5884 - val_mean_squared_error: 0.5909
# Epoch 117/140
# 212/212 [==============================] - 0s 69us/step - loss: 0.5911 - mean_absolute_error: 0.6212 - mean_squared_error: 0.5911 - val_loss: 0.5898 - val_mean_absolute_error: 0.5889 - val_mean_squared_error: 0.5898
# Epoch 118/140
# 212/212 [==============================] - 0s 56us/step - loss: 0.5895 - mean_absolute_error: 0.6199 - mean_squared_error: 0.5895 - val_loss: 0.5894 - val_mean_absolute_error: 0.5893 - val_mean_squared_error: 0.5894
# Epoch 119/140
# 212/212 [==============================] - 0s 54us/step - loss: 0.5894 - mean_absolute_error: 0.6195 - mean_squared_error: 0.5894 - val_loss: 0.5892 - val_mean_absolute_error: 0.5894 - val_mean_squared_error: 0.5892
# Epoch 120/140
# 212/212 [==============================] - 0s 52us/step - loss: 0.5876 - mean_absolute_error: 0.6186 - mean_squared_error: 0.5876 - val_loss: 0.5900 - val_mean_absolute_error: 0.5890 - val_mean_squared_error: 0.5900
# Epoch 121/140
# 212/212 [==============================] - 0s 197us/step - loss: 0.5873 - mean_absolute_error: 0.6185 - mean_squared_error: 0.5873 - val_loss: 0.5910 - val_mean_absolute_error: 0.5887 - val_mean_squared_error: 0.5910
# Epoch 122/140
# 212/212 [==============================] - 0s 62us/step - loss: 0.5875 - mean_absolute_error: 0.6185 - mean_squared_error: 0.5875 - val_loss: 0.5901 - val_mean_absolute_error: 0.5889 - val_mean_squared_error: 0.5901
# Epoch 123/140
# 212/212 [==============================] - 0s 61us/step - loss: 0.5860 - mean_absolute_error: 0.6174 - mean_squared_error: 0.5860 - val_loss: 0.5909 - val_mean_absolute_error: 0.5891 - val_mean_squared_error: 0.5909
# Epoch 124/140
# 212/212 [==============================] - 0s 51us/step - loss: 0.5856 - mean_absolute_error: 0.6174 - mean_squared_error: 0.5856 - val_loss: 0.5904 - val_mean_absolute_error: 0.5894 - val_mean_squared_error: 0.5904
# Epoch 125/140
# 212/212 [==============================] - 0s 51us/step - loss: 0.5842 - mean_absolute_error: 0.6166 - mean_squared_error: 0.5842 - val_loss: 0.5908 - val_mean_absolute_error: 0.5893 - val_mean_squared_error: 0.5908
# Epoch 126/140
# 212/212 [==============================] - 0s 81us/step - loss: 0.5836 - mean_absolute_error: 0.6164 - mean_squared_error: 0.5836 - val_loss: 0.5914 - val_mean_absolute_error: 0.5892 - val_mean_squared_error: 0.5914
# Epoch 127/140
# 212/212 [==============================] - ETA: 0s - loss: 0.4552 - mean_absolute_error: 0.5530 - mean_squared_error: 0.45 - 0s 57us/step - loss: 0.5837 - mean_absolute_error: 0.6165 - mean_squared_error: 0.5837 - val_loss: 0.5918 - val_mean_absolute_error: 0.5892 - val_mean_squared_error: 0.5918
# Epoch 128/140
# 212/212 [==============================] - 0s 51us/step - loss: 0.5827 - mean_absolute_error: 0.6156 - mean_squared_error: 0.5827 - val_loss: 0.5910 - val_mean_absolute_error: 0.5899 - val_mean_squared_error: 0.5910
# Epoch 129/140
# 212/212 [==============================] - 0s 56us/step - loss: 0.5817 - mean_absolute_error: 0.6149 - mean_squared_error: 0.5817 - val_loss: 0.5910 - val_mean_absolute_error: 0.5897 - val_mean_squared_error: 0.5910
# Epoch 130/140
# 212/212 [==============================] - 0s 50us/step - loss: 0.5817 - mean_absolute_error: 0.6150 - mean_squared_error: 0.5817 - val_loss: 0.5907 - val_mean_absolute_error: 0.5899 - val_mean_squared_error: 0.5907
# Epoch 131/140
# 212/212 [==============================] - 0s 195us/step - loss: 0.5815 - mean_absolute_error: 0.6151 - mean_squared_error: 0.5815 - val_loss: 0.5918 - val_mean_absolute_error: 0.5889 - val_mean_squared_error: 0.5918
# Epoch 132/140
# 212/212 [==============================] - 0s 59us/step - loss: 0.5820 - mean_absolute_error: 0.6155 - mean_squared_error: 0.5820 - val_loss: 0.5914 - val_mean_absolute_error: 0.5900 - val_mean_squared_error: 0.5914
# Epoch 133/140
# 212/212 [==============================] - 0s 59us/step - loss: 0.5784 - mean_absolute_error: 0.6132 - mean_squared_error: 0.5784 - val_loss: 0.5918 - val_mean_absolute_error: 0.5898 - val_mean_squared_error: 0.5918
# Epoch 134/140
# 212/212 [==============================] - 0s 60us/step - loss: 0.5792 - mean_absolute_error: 0.6131 - mean_squared_error: 0.5792 - val_loss: 0.5933 - val_mean_absolute_error: 0.5898 - val_mean_squared_error: 0.5933
# Epoch 135/140
# 212/212 [==============================] - 0s 219us/step - loss: 0.5774 - mean_absolute_error: 0.6128 - mean_squared_error: 0.5774 - val_loss: 0.5920 - val_mean_absolute_error: 0.5904 - val_mean_squared_error: 0.5920
# Epoch 136/140
# 212/212 [==============================] - 0s 58us/step - loss: 0.5767 - mean_absolute_error: 0.6119 - mean_squared_error: 0.5767 - val_loss: 0.5926 - val_mean_absolute_error: 0.5909 - val_mean_squared_error: 0.5926
# Epoch 137/140
# 212/212 [==============================] - 0s 64us/step - loss: 0.5756 - mean_absolute_error: 0.6111 - mean_squared_error: 0.5756 - val_loss: 0.5924 - val_mean_absolute_error: 0.5908 - val_mean_squared_error: 0.5924
# Epoch 138/140
# 212/212 [==============================] - 0s 71us/step - loss: 0.5752 - mean_absolute_error: 0.6112 - mean_squared_error: 0.5752 - val_loss: 0.5924 - val_mean_absolute_error: 0.5905 - val_mean_squared_error: 0.5924
# Epoch 139/140
# 212/212 [==============================] - 0s 252us/step - loss: 0.5745 - mean_absolute_error: 0.6107 - mean_squared_error: 0.5745 - val_loss: 0.5927 - val_mean_absolute_error: 0.5907 - val_mean_squared_error: 0.5927
# Epoch 140/140
# 212/212 [==============================] - 0s 59us/step - loss: 0.5763 - mean_absolute_error: 0.6114 - mean_squared_error: 0.5763 - val_loss: 0.5928 - val_mean_absolute_error: 0.5922 - val_mean_squared_error: 0.5928

# %%
# Выводим динамику среднего абсолютного отклонения от номера эпохи обучения.
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error']) 
plt.title('Model MAE') 
plt.ylabel('MAE') 
plt.xlabel('Epoch') 
plt.legend(['Train', 'Test'], loc='upper right') 
plt.show()

# %%
# Выводим динамику среднеквадратического отклонения, т.е. значения функции потерь, от номера эпохи обучения.
plt.plot(history.history['mean_squared_error'])
plt.plot(history.history['val_mean_squared_error']) 
plt.title('Model MSE') 
plt.ylabel('MSE') 
plt.xlabel('Epoch') 
plt.legend(['Train', 'Test'], loc='upper right') 
plt.show()

# %%
# Предсказание уже обученной нейронной сети на обучающей выборке:
Y_pred_train = model.predict(X_train).flatten()

# %%
# Сравним эталонные значения Y_train и результат работы обученной нейронной сети Y_pred_train для обучающей выборки.
plt.plot(Y_train, Y_pred_train, 'bo')
plt.plot([-2,2], [-2,2], 'r-')
plt.title('Test vs Pred_test') 
plt.ylabel('Pred_test') 
plt.xlabel('Test') 
plt.show()

# %%
# Выведем сами значения Y_train и Y_pred_train.
plt.plot(Y_train)
plt.plot(Y_pred_train)
plt.show()

# %%
# Предсказание обученной нейронной сети на тестовой выборке:
Y_pred_test = model.predict(X_test).flatten()

# %%
# Сравним эталонные значения Y_test и результат работы обученной нейронной сети Y_pred_test для тестовой выборки.
plt.plot(Y_test, Y_pred_test, 'bo')
plt.plot([-2,2], [-2,2], 'r-')
plt.title('Test vs Pred_test') 
plt.ylabel('Pred_test') 
plt.xlabel('Test') 
plt.show()

# %%
# Выведем сами значения Y_test и Y_pred_test.
plt.plot(Y_test)
plt.plot(Y_pred_test)
plt.show()

# %%
# Сравним среднеквадратичные ошибки (значения функции потерь) для обучающей и тестовой выборок.
print(np.sqrt(mean_squared_error(Y_train, Y_pred_train)))
print(np.sqrt(mean_squared_error(Y_test, Y_pred_test)))
# Out:
# 0.7571609692975554
# 0.7699656071908616

# %%
# Проверим на нормальное распределение разности пар (Y_train, Y_pred_train), (Y_test, Y_pred_test)
k_train, p_train = stats.shapiro(Y_train - Y_pred_train)
print('Train k = {0}, p = {1}'.format(k_train, p_train))

k_test, p_test = stats.shapiro(Y_test - Y_pred_test)
print('Test k = {0}, p = {1}'.format(k_test, p_test))
# Out:
# Train k = 0.9883134961128235, p = 0.08076103776693344
# Test k = 0.9834527969360352, p = 0.30309778451919556

# %%
# Для полной выборки (Y, Y_pred) применим два статистических теста: shapiro и normaltest.
Y_pred = model.predict(X).flatten()

k_s, p_s = stats.shapiro(Y - Y_pred)
print('k_s = {0}, p_s = {1}'.format(k_s, p_s))

k_n, p_n = stats.normaltest(Y - Y_pred)
print('k_n = {0}, p_n = {1}'.format(k_n, p_n))
# Out:
# k_s = 0.9890581369400024, p_s = 0.02230231463909149
# k_n = 8.076240839847216, p_n = 0.01763057937801736

# %%
# И тоже самое визуально, с помощью грфиков квантиль-квантиль.
# Обучающая выборка
qqplot(Y_train - Y_pred_train)
plt.show()

# %%
# Тестовая выборка
qqplot(Y_test - Y_pred_test)
plt.show()

# %%
# Полная выборка
qqplot(Y - Y_pred)
plt.show()

# %%
plt.hist(Y - Y_pred, bins=50)
plt.show()

# %%
model.save('SimpleNeuralNetwork.h5')
