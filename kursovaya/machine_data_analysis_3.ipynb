# %%
# Загрузка зависимостей
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import keras
from keras.models import Sequential
from keras.layers import Dense
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from scipy import stats
from statsmodels.graphics.gofplots import qqplot
# Out:
# Using TensorFlow backend.

# %%
# Загрузка подготовленного набора данных
dataset = pd.read_csv('prepared_data.csv')
dataset.head(10)
# Out:
#         age  sex        cp  trestbps      chol  fbs   restecg   thalach  \
# 0  0.927622  1.0  1.000000  0.624287  0.410173  1.0  0.000000  0.090789
# 1 -2.117138  1.0  0.816497  0.454038  0.457160  0.0  0.707107  1.444548
# 2 -1.529863  0.0  0.577350  0.454038  0.321489  0.0  0.000000  0.931137
# 3  0.253797  1.0  0.577350  0.335019  0.418709  0.0  0.707107  1.141680
# 4  0.355054  0.0  0.000000  0.335019  0.689241  0.0  0.707107  0.601134
# 5  0.355054  1.0  0.000000  0.568560  0.281039  0.0  0.707107  0.008368
# 6  0.253797  0.0  0.577350  0.568560  0.565328  0.0  0.000000  0.212382
# 7 -1.125867  1.0  0.577350  0.335019  0.490983  0.0  0.707107  0.966733
# 8 -0.170168  1.0  0.816497  0.909866  0.304932  1.0  0.707107  0.563348
# 9  0.355054  1.0  0.816497  0.679061  0.191945  0.0  0.707107  1.002123
#
#    exang   oldpeak     slope   ca  num
# 0    0.0  0.552201  0.000000  0.0  1.0
# 1    0.0  0.715169  0.000000  0.0  1.0
# 2    0.0  0.398844  1.000000  0.0  1.0
# 3    0.0  0.265991  1.000000  0.0  1.0
# 4    1.0  0.210865  1.000000  0.0  1.0
# 5    0.0  0.145476  0.707107  0.0  1.0
# 6    0.0  0.379044  0.707107  0.0  1.0
# 7    0.0  0.314559  1.000000  0.0  1.0
# 8    0.0  0.179818  1.000000  0.0  1.0
# 9    0.0  0.436427  1.000000  0.0  1.0

# %%
X = dataset.drop(columns=['age']).values
Y = dataset['age'].values

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.4)

# %%
# Задаем параметры структуры нейронной сети.


input_layer_size = 12


first_hidden_layer_size = 10
second_hidden_layer_size = 10
third_hidden_layer_size = 60

output_layer_size = 1


epochs_number = 105
batch_size = 36

# %%
# Создание нейронной сети прямого распространения, пока она пустая, т.е. не содержит слоёв и нейронов.
model = Sequential()

# Входной слой и первый скрытый слой, функция активации - ReLU
model.add(Dense(first_hidden_layer_size, input_dim=input_layer_size, activation='relu'))

model.add(Dense(second_hidden_layer_size, activation='relu'))


model.add(Dense(output_layer_size, activation='linear'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 10)                130
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                110
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 251
# Trainable params: 251
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Настройка нейронной сети.
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error', 'mean_squared_error'])

# %%
# Обучение нейронной сети.
history = model.fit(X_train, Y_train, validation_data = (X_test,Y_test), epochs=epochs_number, batch_size=batch_size)
# Out:
# Train on 181 samples, validate on 122 samples
# Epoch 1/105
# 181/181 [==============================] - 0s 2ms/step - loss: 1.1431 - mean_absolute_error: 0.9150 - mean_squared_error: 1.1431 - val_loss: 1.1962 - val_mean_absolute_error: 0.8954 - val_mean_squared_error: 1.1962
# Epoch 2/105
# 181/181 [==============================] - 0s 238us/step - loss: 1.1119 - mean_absolute_error: 0.8979 - mean_squared_error: 1.1119 - val_loss: 1.1408 - val_mean_absolute_error: 0.8712 - val_mean_squared_error: 1.1408
# Epoch 3/105
# 181/181 [==============================] - 0s 127us/step - loss: 1.0908 - mean_absolute_error: 0.8856 - mean_squared_error: 1.0908 - val_loss: 1.0965 - val_mean_absolute_error: 0.8508 - val_mean_squared_error: 1.0965
# Epoch 4/105
# 181/181 [==============================] - 0s 95us/step - loss: 1.0738 - mean_absolute_error: 0.8747 - mean_squared_error: 1.0738 - val_loss: 1.0630 - val_mean_absolute_error: 0.8352 - val_mean_squared_error: 1.0630
# Epoch 5/105
# 181/181 [==============================] - 0s 81us/step - loss: 1.0624 - mean_absolute_error: 0.8669 - mean_squared_error: 1.0624 - val_loss: 1.0329 - val_mean_absolute_error: 0.8209 - val_mean_squared_error: 1.0329
# Epoch 6/105
# 181/181 [==============================] - 0s 248us/step - loss: 1.0535 - mean_absolute_error: 0.8606 - mean_squared_error: 1.0535 - val_loss: 1.0126 - val_mean_absolute_error: 0.8122 - val_mean_squared_error: 1.0126
# Epoch 7/105
# 181/181 [==============================] - 0s 88us/step - loss: 1.0449 - mean_absolute_error: 0.8560 - mean_squared_error: 1.0449 - val_loss: 0.9966 - val_mean_absolute_error: 0.8056 - val_mean_squared_error: 0.9966
# Epoch 8/105
# 181/181 [==============================] - 0s 87us/step - loss: 1.0366 - mean_absolute_error: 0.8514 - mean_squared_error: 1.0366 - val_loss: 0.9818 - val_mean_absolute_error: 0.7996 - val_mean_squared_error: 0.9818
# Epoch 9/105
# 181/181 [==============================] - 0s 262us/step - loss: 1.0310 - mean_absolute_error: 0.8480 - mean_squared_error: 1.0310 - val_loss: 0.9693 - val_mean_absolute_error: 0.7953 - val_mean_squared_error: 0.9693
# Epoch 10/105
# 181/181 [==============================] - 0s 105us/step - loss: 1.0257 - mean_absolute_error: 0.8451 - mean_squared_error: 1.0257 - val_loss: 0.9564 - val_mean_absolute_error: 0.7906 - val_mean_squared_error: 0.9564
# Epoch 11/105
# 181/181 [==============================] - 0s 80us/step - loss: 1.0189 - mean_absolute_error: 0.8417 - mean_squared_error: 1.0189 - val_loss: 0.9457 - val_mean_absolute_error: 0.7867 - val_mean_squared_error: 0.9457
# Epoch 12/105
# 181/181 [==============================] - 0s 108us/step - loss: 1.0136 - mean_absolute_error: 0.8386 - mean_squared_error: 1.0136 - val_loss: 0.9378 - val_mean_absolute_error: 0.7838 - val_mean_squared_error: 0.9378
# Epoch 13/105
# 181/181 [==============================] - 0s 251us/step - loss: 1.0104 - mean_absolute_error: 0.8386 - mean_squared_error: 1.0104 - val_loss: 0.9457 - val_mean_absolute_error: 0.7888 - val_mean_squared_error: 0.9457
# Epoch 14/105
# 181/181 [==============================] - 0s 106us/step - loss: 1.0062 - mean_absolute_error: 0.8383 - mean_squared_error: 1.0062 - val_loss: 0.9440 - val_mean_absolute_error: 0.7885 - val_mean_squared_error: 0.9440
# Epoch 15/105
# 181/181 [==============================] - 0s 97us/step - loss: 1.0026 - mean_absolute_error: 0.8378 - mean_squared_error: 1.0026 - val_loss: 0.9454 - val_mean_absolute_error: 0.7908 - val_mean_squared_error: 0.9454
# Epoch 16/105
# 181/181 [==============================] - 0s 292us/step - loss: 0.9985 - mean_absolute_error: 0.8373 - mean_squared_error: 0.9985 - val_loss: 0.9416 - val_mean_absolute_error: 0.7899 - val_mean_squared_error: 0.9416
# Epoch 17/105
# 181/181 [==============================] - 0s 86us/step - loss: 0.9941 - mean_absolute_error: 0.8351 - mean_squared_error: 0.9941 - val_loss: 0.9317 - val_mean_absolute_error: 0.7852 - val_mean_squared_error: 0.9317
# Epoch 18/105
# 181/181 [==============================] - 0s 87us/step - loss: 0.9893 - mean_absolute_error: 0.8322 - mean_squared_error: 0.9893 - val_loss: 0.9240 - val_mean_absolute_error: 0.7818 - val_mean_squared_error: 0.9240
# Epoch 19/105
# 181/181 [==============================] - 0s 246us/step - loss: 0.9861 - mean_absolute_error: 0.8293 - mean_squared_error: 0.9861 - val_loss: 0.9134 - val_mean_absolute_error: 0.7770 - val_mean_squared_error: 0.9134
# Epoch 20/105
# 181/181 [==============================] - 0s 95us/step - loss: 0.9797 - mean_absolute_error: 0.8273 - mean_squared_error: 0.9797 - val_loss: 0.9184 - val_mean_absolute_error: 0.7806 - val_mean_squared_error: 0.9184
# Epoch 21/105
# 181/181 [==============================] - 0s 89us/step - loss: 0.9766 - mean_absolute_error: 0.8270 - mean_squared_error: 0.9766 - val_loss: 0.9163 - val_mean_absolute_error: 0.7799 - val_mean_squared_error: 0.9163
# Epoch 22/105
# 181/181 [==============================] - 0s 80us/step - loss: 0.9721 - mean_absolute_error: 0.8243 - mean_squared_error: 0.9721 - val_loss: 0.9083 - val_mean_absolute_error: 0.7761 - val_mean_squared_error: 0.9083
# Epoch 23/105
# 181/181 [==============================] - 0s 279us/step - loss: 0.9665 - mean_absolute_error: 0.8214 - mean_squared_error: 0.9665 - val_loss: 0.9014 - val_mean_absolute_error: 0.7743 - val_mean_squared_error: 0.9014
# Epoch 24/105
# 181/181 [==============================] - 0s 88us/step - loss: 0.9601 - mean_absolute_error: 0.8188 - mean_squared_error: 0.9601 - val_loss: 0.8943 - val_mean_absolute_error: 0.7725 - val_mean_squared_error: 0.8943
# Epoch 25/105
# 181/181 [==============================] - 0s 90us/step - loss: 0.9514 - mean_absolute_error: 0.8161 - mean_squared_error: 0.9514 - val_loss: 0.8927 - val_mean_absolute_error: 0.7743 - val_mean_squared_error: 0.8927
# Epoch 26/105
# 181/181 [==============================] - 0s 73us/step - loss: 0.9436 - mean_absolute_error: 0.8133 - mean_squared_error: 0.9436 - val_loss: 0.8853 - val_mean_absolute_error: 0.7719 - val_mean_squared_error: 0.8853
# Epoch 27/105
# 181/181 [==============================] - 0s 251us/step - loss: 0.9357 - mean_absolute_error: 0.8103 - mean_squared_error: 0.9357 - val_loss: 0.8812 - val_mean_absolute_error: 0.7720 - val_mean_squared_error: 0.8812
# Epoch 28/105
# 181/181 [==============================] - 0s 85us/step - loss: 0.9287 - mean_absolute_error: 0.8079 - mean_squared_error: 0.9287 - val_loss: 0.8734 - val_mean_absolute_error: 0.7694 - val_mean_squared_error: 0.8734
# Epoch 29/105
# 181/181 [==============================] - 0s 79us/step - loss: 0.9198 - mean_absolute_error: 0.8050 - mean_squared_error: 0.9198 - val_loss: 0.8692 - val_mean_absolute_error: 0.7701 - val_mean_squared_error: 0.8692
# Epoch 30/105
# 181/181 [==============================] - 0s 309us/step - loss: 0.9107 - mean_absolute_error: 0.8021 - mean_squared_error: 0.9107 - val_loss: 0.8674 - val_mean_absolute_error: 0.7720 - val_mean_squared_error: 0.8674
# Epoch 31/105
# 181/181 [==============================] - 0s 94us/step - loss: 0.9033 - mean_absolute_error: 0.8012 - mean_squared_error: 0.9033 - val_loss: 0.8634 - val_mean_absolute_error: 0.7720 - val_mean_squared_error: 0.8634
# Epoch 32/105
# 181/181 [==============================] - 0s 71us/step - loss: 0.8930 - mean_absolute_error: 0.7960 - mean_squared_error: 0.8930 - val_loss: 0.8465 - val_mean_absolute_error: 0.7641 - val_mean_squared_error: 0.8465
# Epoch 33/105
# 181/181 [==============================] - 0s 79us/step - loss: 0.8835 - mean_absolute_error: 0.7905 - mean_squared_error: 0.8835 - val_loss: 0.8306 - val_mean_absolute_error: 0.7559 - val_mean_squared_error: 0.8306
# Epoch 34/105
# 181/181 [==============================] - 0s 244us/step - loss: 0.8729 - mean_absolute_error: 0.7832 - mean_squared_error: 0.8729 - val_loss: 0.8101 - val_mean_absolute_error: 0.7446 - val_mean_squared_error: 0.8101
# Epoch 35/105
# 181/181 [==============================] - 0s 86us/step - loss: 0.8657 - mean_absolute_error: 0.7773 - mean_squared_error: 0.8657 - val_loss: 0.7910 - val_mean_absolute_error: 0.7333 - val_mean_squared_error: 0.7910
# Epoch 36/105
# 181/181 [==============================] - 0s 79us/step - loss: 0.8580 - mean_absolute_error: 0.7715 - mean_squared_error: 0.8580 - val_loss: 0.7786 - val_mean_absolute_error: 0.7263 - val_mean_squared_error: 0.7786
# Epoch 37/105
# 181/181 [==============================] - 0s 80us/step - loss: 0.8532 - mean_absolute_error: 0.7664 - mean_squared_error: 0.8532 - val_loss: 0.7653 - val_mean_absolute_error: 0.7177 - val_mean_squared_error: 0.7653
# Epoch 38/105
# 181/181 [==============================] - 0s 297us/step - loss: 0.8495 - mean_absolute_error: 0.7628 - mean_squared_error: 0.8495 - val_loss: 0.7562 - val_mean_absolute_error: 0.7118 - val_mean_squared_error: 0.7562
# Epoch 39/105
# 181/181 [==============================] - 0s 66us/step - loss: 0.8470 - mean_absolute_error: 0.7604 - mean_squared_error: 0.8470 - val_loss: 0.7465 - val_mean_absolute_error: 0.7052 - val_mean_squared_error: 0.7465
# Epoch 40/105
# 181/181 [==============================] - 0s 65us/step - loss: 0.8437 - mean_absolute_error: 0.7569 - mean_squared_error: 0.8437 - val_loss: 0.7351 - val_mean_absolute_error: 0.6971 - val_mean_squared_error: 0.7351
# Epoch 41/105
# 181/181 [==============================] - 0s 65us/step - loss: 0.8388 - mean_absolute_error: 0.7536 - mean_squared_error: 0.8388 - val_loss: 0.7275 - val_mean_absolute_error: 0.6924 - val_mean_squared_error: 0.7275
# Epoch 42/105
# 181/181 [==============================] - 0s 283us/step - loss: 0.8373 - mean_absolute_error: 0.7522 - mean_squared_error: 0.8373 - val_loss: 0.7219 - val_mean_absolute_error: 0.6888 - val_mean_squared_error: 0.7219
# Epoch 43/105
# 181/181 [==============================] - 0s 74us/step - loss: 0.8287 - mean_absolute_error: 0.7486 - mean_squared_error: 0.8287 - val_loss: 0.7194 - val_mean_absolute_error: 0.6909 - val_mean_squared_error: 0.7194
# Epoch 44/105
# 181/181 [==============================] - 0s 65us/step - loss: 0.8225 - mean_absolute_error: 0.7473 - mean_squared_error: 0.8225 - val_loss: 0.7224 - val_mean_absolute_error: 0.6962 - val_mean_squared_error: 0.7224
# Epoch 45/105
# 181/181 [==============================] - 0s 77us/step - loss: 0.8103 - mean_absolute_error: 0.7434 - mean_squared_error: 0.8103 - val_loss: 0.7202 - val_mean_absolute_error: 0.6959 - val_mean_squared_error: 0.7202
# Epoch 46/105
# 181/181 [==============================] - 0s 281us/step - loss: 0.8066 - mean_absolute_error: 0.7418 - mean_squared_error: 0.8066 - val_loss: 0.7134 - val_mean_absolute_error: 0.6921 - val_mean_squared_error: 0.7134
# Epoch 47/105
# 181/181 [==============================] - 0s 92us/step - loss: 0.8021 - mean_absolute_error: 0.7390 - mean_squared_error: 0.8021 - val_loss: 0.7055 - val_mean_absolute_error: 0.6877 - val_mean_squared_error: 0.7055
# Epoch 48/105
# 181/181 [==============================] - 0s 108us/step - loss: 0.7973 - mean_absolute_error: 0.7361 - mean_squared_error: 0.7973 - val_loss: 0.7013 - val_mean_absolute_error: 0.6863 - val_mean_squared_error: 0.7013
# Epoch 49/105
# 181/181 [==============================] - 0s 90us/step - loss: 0.7924 - mean_absolute_error: 0.7338 - mean_squared_error: 0.7924 - val_loss: 0.6957 - val_mean_absolute_error: 0.6831 - val_mean_squared_error: 0.6957
# Epoch 50/105
# 181/181 [==============================] - 0s 104us/step - loss: 0.7899 - mean_absolute_error: 0.7320 - mean_squared_error: 0.7899 - val_loss: 0.6951 - val_mean_absolute_error: 0.6831 - val_mean_squared_error: 0.6951
# Epoch 51/105
# 181/181 [==============================] - 0s 85us/step - loss: 0.7865 - mean_absolute_error: 0.7307 - mean_squared_error: 0.7865 - val_loss: 0.7007 - val_mean_absolute_error: 0.6876 - val_mean_squared_error: 0.7007
# Epoch 52/105
# 181/181 [==============================] - 0s 85us/step - loss: 0.7832 - mean_absolute_error: 0.7293 - mean_squared_error: 0.7832 - val_loss: 0.7034 - val_mean_absolute_error: 0.6916 - val_mean_squared_error: 0.7034
# Epoch 53/105
# 181/181 [==============================] - 0s 78us/step - loss: 0.7783 - mean_absolute_error: 0.7269 - mean_squared_error: 0.7783 - val_loss: 0.6952 - val_mean_absolute_error: 0.6873 - val_mean_squared_error: 0.6952
# Epoch 54/105
# 181/181 [==============================] - 0s 217us/step - loss: 0.7726 - mean_absolute_error: 0.7239 - mean_squared_error: 0.7726 - val_loss: 0.6842 - val_mean_absolute_error: 0.6790 - val_mean_squared_error: 0.6842
# Epoch 55/105
# 181/181 [==============================] - 0s 80us/step - loss: 0.7701 - mean_absolute_error: 0.7221 - mean_squared_error: 0.7701 - val_loss: 0.6810 - val_mean_absolute_error: 0.6769 - val_mean_squared_error: 0.6810
# Epoch 56/105
# 181/181 [==============================] - 0s 81us/step - loss: 0.7675 - mean_absolute_error: 0.7206 - mean_squared_error: 0.7675 - val_loss: 0.6789 - val_mean_absolute_error: 0.6763 - val_mean_squared_error: 0.6789
# Epoch 57/105
# 181/181 [==============================] - 0s 292us/step - loss: 0.7646 - mean_absolute_error: 0.7190 - mean_squared_error: 0.7646 - val_loss: 0.6742 - val_mean_absolute_error: 0.6737 - val_mean_squared_error: 0.6742
# Epoch 58/105
# 181/181 [==============================] - 0s 78us/step - loss: 0.7615 - mean_absolute_error: 0.7172 - mean_squared_error: 0.7615 - val_loss: 0.6691 - val_mean_absolute_error: 0.6703 - val_mean_squared_error: 0.6691
# Epoch 59/105
# 181/181 [==============================] - 0s 68us/step - loss: 0.7583 - mean_absolute_error: 0.7153 - mean_squared_error: 0.7583 - val_loss: 0.6656 - val_mean_absolute_error: 0.6678 - val_mean_squared_error: 0.6656
# Epoch 60/105
# 181/181 [==============================] - 0s 91us/step - loss: 0.7554 - mean_absolute_error: 0.7138 - mean_squared_error: 0.7554 - val_loss: 0.6671 - val_mean_absolute_error: 0.6697 - val_mean_squared_error: 0.6671
# Epoch 61/105
# 181/181 [==============================] - 0s 247us/step - loss: 0.7518 - mean_absolute_error: 0.7120 - mean_squared_error: 0.7518 - val_loss: 0.6710 - val_mean_absolute_error: 0.6731 - val_mean_squared_error: 0.6710
# Epoch 62/105
# 181/181 [==============================] - 0s 79us/step - loss: 0.7475 - mean_absolute_error: 0.7091 - mean_squared_error: 0.7475 - val_loss: 0.6773 - val_mean_absolute_error: 0.6787 - val_mean_squared_error: 0.6773
# Epoch 63/105
# 181/181 [==============================] - 0s 81us/step - loss: 0.7465 - mean_absolute_error: 0.7075 - mean_squared_error: 0.7465 - val_loss: 0.6852 - val_mean_absolute_error: 0.6864 - val_mean_squared_error: 0.6852
# Epoch 64/105
# 181/181 [==============================] - 0s 82us/step - loss: 0.7462 - mean_absolute_error: 0.7062 - mean_squared_error: 0.7462 - val_loss: 0.6864 - val_mean_absolute_error: 0.6880 - val_mean_squared_error: 0.6864
# Epoch 65/105
# 181/181 [==============================] - 0s 69us/step - loss: 0.7429 - mean_absolute_error: 0.7050 - mean_squared_error: 0.7429 - val_loss: 0.6757 - val_mean_absolute_error: 0.6802 - val_mean_squared_error: 0.6757
# Epoch 66/105
# 181/181 [==============================] - 0s 249us/step - loss: 0.7362 - mean_absolute_error: 0.7016 - mean_squared_error: 0.7362 - val_loss: 0.6715 - val_mean_absolute_error: 0.6773 - val_mean_squared_error: 0.6715
# Epoch 67/105
# 181/181 [==============================] - 0s 72us/step - loss: 0.7328 - mean_absolute_error: 0.6998 - mean_squared_error: 0.7328 - val_loss: 0.6704 - val_mean_absolute_error: 0.6765 - val_mean_squared_error: 0.6704
# Epoch 68/105
# 181/181 [==============================] - 0s 60us/step - loss: 0.7298 - mean_absolute_error: 0.6984 - mean_squared_error: 0.7298 - val_loss: 0.6631 - val_mean_absolute_error: 0.6710 - val_mean_squared_error: 0.6631
# Epoch 69/105
# 181/181 [==============================] - ETA: 0s - loss: 0.6603 - mean_absolute_error: 0.6059 - mean_squared_error: 0.66 - 0s 61us/step - loss: 0.7244 - mean_absolute_error: 0.6957 - mean_squared_error: 0.7244 - val_loss: 0.6553 - val_mean_absolute_error: 0.6648 - val_mean_squared_error: 0.6553
# Epoch 70/105
# 181/181 [==============================] - 0s 222us/step - loss: 0.7215 - mean_absolute_error: 0.6938 - mean_squared_error: 0.7215 - val_loss: 0.6476 - val_mean_absolute_error: 0.6582 - val_mean_squared_error: 0.6476
# Epoch 71/105
# 181/181 [==============================] - 0s 87us/step - loss: 0.7193 - mean_absolute_error: 0.6923 - mean_squared_error: 0.7193 - val_loss: 0.6484 - val_mean_absolute_error: 0.6587 - val_mean_squared_error: 0.6484
# Epoch 72/105
# 181/181 [==============================] - 0s 75us/step - loss: 0.7154 - mean_absolute_error: 0.6905 - mean_squared_error: 0.7154 - val_loss: 0.6507 - val_mean_absolute_error: 0.6612 - val_mean_squared_error: 0.6507
# Epoch 73/105
# 181/181 [==============================] - 0s 79us/step - loss: 0.7122 - mean_absolute_error: 0.6884 - mean_squared_error: 0.7122 - val_loss: 0.6451 - val_mean_absolute_error: 0.6570 - val_mean_squared_error: 0.6451
# Epoch 74/105
# 181/181 [==============================] - 0s 262us/step - loss: 0.7102 - mean_absolute_error: 0.6869 - mean_squared_error: 0.7102 - val_loss: 0.6374 - val_mean_absolute_error: 0.6503 - val_mean_squared_error: 0.6374
# Epoch 75/105
# 181/181 [==============================] - 0s 89us/step - loss: 0.7078 - mean_absolute_error: 0.6859 - mean_squared_error: 0.7078 - val_loss: 0.6316 - val_mean_absolute_error: 0.6439 - val_mean_squared_error: 0.6316
# Epoch 76/105
# 181/181 [==============================] - 0s 78us/step - loss: 0.7137 - mean_absolute_error: 0.6879 - mean_squared_error: 0.7137 - val_loss: 0.6289 - val_mean_absolute_error: 0.6394 - val_mean_squared_error: 0.6289
# Epoch 77/105
# 181/181 [==============================] - 0s 64us/step - loss: 0.7151 - mean_absolute_error: 0.6881 - mean_squared_error: 0.7151 - val_loss: 0.6287 - val_mean_absolute_error: 0.6382 - val_mean_squared_error: 0.6287
# Epoch 78/105
# 181/181 [==============================] - 0s 263us/step - loss: 0.7124 - mean_absolute_error: 0.6860 - mean_squared_error: 0.7124 - val_loss: 0.6300 - val_mean_absolute_error: 0.6418 - val_mean_squared_error: 0.6300
# Epoch 79/105
# 181/181 [==============================] - 0s 79us/step - loss: 0.6992 - mean_absolute_error: 0.6806 - mean_squared_error: 0.6992 - val_loss: 0.6374 - val_mean_absolute_error: 0.6508 - val_mean_squared_error: 0.6374
# Epoch 80/105
# 181/181 [==============================] - 0s 73us/step - loss: 0.6911 - mean_absolute_error: 0.6764 - mean_squared_error: 0.6911 - val_loss: 0.6427 - val_mean_absolute_error: 0.6556 - val_mean_squared_error: 0.6427
# Epoch 81/105
# 181/181 [==============================] - 0s 68us/step - loss: 0.6861 - mean_absolute_error: 0.6743 - mean_squared_error: 0.6861 - val_loss: 0.6507 - val_mean_absolute_error: 0.6612 - val_mean_squared_error: 0.6507
# Epoch 82/105
# 181/181 [==============================] - 0s 266us/step - loss: 0.6857 - mean_absolute_error: 0.6740 - mean_squared_error: 0.6857 - val_loss: 0.6493 - val_mean_absolute_error: 0.6606 - val_mean_squared_error: 0.6493
# Epoch 83/105
# 181/181 [==============================] - 0s 68us/step - loss: 0.6822 - mean_absolute_error: 0.6716 - mean_squared_error: 0.6822 - val_loss: 0.6443 - val_mean_absolute_error: 0.6575 - val_mean_squared_error: 0.6443
# Epoch 84/105
# 181/181 [==============================] - 0s 71us/step - loss: 0.6791 - mean_absolute_error: 0.6698 - mean_squared_error: 0.6791 - val_loss: 0.6469 - val_mean_absolute_error: 0.6595 - val_mean_squared_error: 0.6469
# Epoch 85/105
# 181/181 [==============================] - 0s 78us/step - loss: 0.6761 - mean_absolute_error: 0.6687 - mean_squared_error: 0.6761 - val_loss: 0.6505 - val_mean_absolute_error: 0.6621 - val_mean_squared_error: 0.6505
# Epoch 86/105
# 181/181 [==============================] - 0s 276us/step - loss: 0.6745 - mean_absolute_error: 0.6679 - mean_squared_error: 0.6745 - val_loss: 0.6529 - val_mean_absolute_error: 0.6635 - val_mean_squared_error: 0.6529
# Epoch 87/105
# 181/181 [==============================] - 0s 85us/step - loss: 0.6703 - mean_absolute_error: 0.6657 - mean_squared_error: 0.6703 - val_loss: 0.6449 - val_mean_absolute_error: 0.6565 - val_mean_squared_error: 0.6449
# Epoch 88/105
# 181/181 [==============================] - 0s 62us/step - loss: 0.6678 - mean_absolute_error: 0.6643 - mean_squared_error: 0.6678 - val_loss: 0.6392 - val_mean_absolute_error: 0.6511 - val_mean_squared_error: 0.6392
# Epoch 89/105
# 181/181 [==============================] - 0s 74us/step - loss: 0.6680 - mean_absolute_error: 0.6638 - mean_squared_error: 0.6680 - val_loss: 0.6349 - val_mean_absolute_error: 0.6470 - val_mean_squared_error: 0.6349
# Epoch 90/105
# 181/181 [==============================] - 0s 287us/step - loss: 0.6706 - mean_absolute_error: 0.6640 - mean_squared_error: 0.6706 - val_loss: 0.6312 - val_mean_absolute_error: 0.6412 - val_mean_squared_error: 0.6312
# Epoch 91/105
# 181/181 [==============================] - 0s 84us/step - loss: 0.6786 - mean_absolute_error: 0.6669 - mean_squared_error: 0.6786 - val_loss: 0.6312 - val_mean_absolute_error: 0.6367 - val_mean_squared_error: 0.6312
# Epoch 92/105
# 181/181 [==============================] - 0s 81us/step - loss: 0.6798 - mean_absolute_error: 0.6664 - mean_squared_error: 0.6798 - val_loss: 0.6325 - val_mean_absolute_error: 0.6376 - val_mean_squared_error: 0.6325
# Epoch 93/105
# 181/181 [==============================] - 0s 82us/step - loss: 0.6806 - mean_absolute_error: 0.6664 - mean_squared_error: 0.6806 - val_loss: 0.6341 - val_mean_absolute_error: 0.6362 - val_mean_squared_error: 0.6341
# Epoch 94/105
# 181/181 [==============================] - 0s 242us/step - loss: 0.6745 - mean_absolute_error: 0.6636 - mean_squared_error: 0.6745 - val_loss: 0.6358 - val_mean_absolute_error: 0.6403 - val_mean_squared_error: 0.6358
# Epoch 95/105
# 181/181 [==============================] - 0s 105us/step - loss: 0.6646 - mean_absolute_error: 0.6600 - mean_squared_error: 0.6646 - val_loss: 0.6406 - val_mean_absolute_error: 0.6467 - val_mean_squared_error: 0.6406
# Epoch 96/105
# 181/181 [==============================] - 0s 65us/step - loss: 0.6582 - mean_absolute_error: 0.6570 - mean_squared_error: 0.6582 - val_loss: 0.6415 - val_mean_absolute_error: 0.6489 - val_mean_squared_error: 0.6415
# Epoch 97/105
# 181/181 [==============================] - 0s 64us/step - loss: 0.6547 - mean_absolute_error: 0.6554 - mean_squared_error: 0.6547 - val_loss: 0.6431 - val_mean_absolute_error: 0.6513 - val_mean_squared_error: 0.6431
# Epoch 98/105
# 181/181 [==============================] - 0s 238us/step - loss: 0.6521 - mean_absolute_error: 0.6536 - mean_squared_error: 0.6521 - val_loss: 0.6454 - val_mean_absolute_error: 0.6539 - val_mean_squared_error: 0.6454
# Epoch 99/105
# 181/181 [==============================] - 0s 83us/step - loss: 0.6501 - mean_absolute_error: 0.6523 - mean_squared_error: 0.6501 - val_loss: 0.6404 - val_mean_absolute_error: 0.6487 - val_mean_squared_error: 0.6404
# Epoch 100/105
# 181/181 [==============================] - 0s 74us/step - loss: 0.6519 - mean_absolute_error: 0.6522 - mean_squared_error: 0.6519 - val_loss: 0.6379 - val_mean_absolute_error: 0.6448 - val_mean_squared_error: 0.6379
# Epoch 101/105
# 181/181 [==============================] - 0s 78us/step - loss: 0.6511 - mean_absolute_error: 0.6512 - mean_squared_error: 0.6511 - val_loss: 0.6378 - val_mean_absolute_error: 0.6441 - val_mean_squared_error: 0.6378
# Epoch 102/105
# 181/181 [==============================] - 0s 70us/step - loss: 0.6491 - mean_absolute_error: 0.6495 - mean_squared_error: 0.6491 - val_loss: 0.6386 - val_mean_absolute_error: 0.6442 - val_mean_squared_error: 0.6386
# Epoch 103/105
# 181/181 [==============================] - 0s 96us/step - loss: 0.6453 - mean_absolute_error: 0.6479 - mean_squared_error: 0.6453 - val_loss: 0.6440 - val_mean_absolute_error: 0.6499 - val_mean_squared_error: 0.6440
# Epoch 104/105
# 181/181 [==============================] - 0s 90us/step - loss: 0.6411 - mean_absolute_error: 0.6458 - mean_squared_error: 0.6411 - val_loss: 0.6479 - val_mean_absolute_error: 0.6534 - val_mean_squared_error: 0.6479
# Epoch 105/105
# 181/181 [==============================] - 0s 79us/step - loss: 0.6387 - mean_absolute_error: 0.6440 - mean_squared_error: 0.6387 - val_loss: 0.6481 - val_mean_absolute_error: 0.6530 - val_mean_squared_error: 0.6481

# %%
# Выводим динамику среднего абсолютного отклонения от номера эпохи обучения.
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error']) 
plt.title('Model MAE') 
plt.ylabel('MAE') 
plt.xlabel('Epoch') 
plt.legend(['Train', 'Test'], loc='upper right') 
plt.show()

# %%
# Выводим динамику среднеквадратического отклонения, т.е. значения функции потерь, от номера эпохи обучения.
plt.plot(history.history['mean_squared_error'])
plt.plot(history.history['val_mean_squared_error']) 
plt.title('Model MSE') 
plt.ylabel('MSE') 
plt.xlabel('Epoch') 
plt.legend(['Train', 'Test'], loc='upper right') 
plt.show()

# %%
# Предсказание уже обученной нейронной сети на обучающей выборке:
Y_pred_train = model.predict(X_train).flatten()

# %%
# Сравним эталонные значения Y_train и результат работы обученной нейронной сети Y_pred_train для обучающей выборки.
plt.plot(Y_train, Y_pred_train, 'bo')
plt.plot([-2,2], [-2,2], 'r-')
plt.title('Test vs Pred_test') 
plt.ylabel('Pred_test') 
plt.xlabel('Test') 
plt.show()

# %%
# Выведем сами значения Y_train и Y_pred_train.
plt.plot(Y_train)
plt.plot(Y_pred_train)
plt.show()

# %%
# Предсказание обученной нейронной сети на тестовой выборке:
Y_pred_test = model.predict(X_test).flatten()

# %%
# Сравним эталонные значения Y_test и результат работы обученной нейронной сети Y_pred_test для тестовой выборки.
plt.plot(Y_test, Y_pred_test, 'bo')
plt.plot([-2,2], [-2,2], 'r-')
plt.title('Test vs Pred_test') 
plt.ylabel('Pred_test') 
plt.xlabel('Test') 
plt.show()

# %%
# Выведем сами значения Y_test и Y_pred_test.
plt.plot(Y_test)
plt.plot(Y_pred_test)
plt.show()

# %%
# Сравним среднеквадратичные ошибки (значения функции потерь) для обучающей и тестовой выборок.
print(np.sqrt(mean_squared_error(Y_train, Y_pred_train)))
print(np.sqrt(mean_squared_error(Y_test, Y_pred_test)))
# Out:
# 0.798338259751941
# 0.8050224793774026

# %%
# Проверим на нормальное распределение разности пар (Y_train, Y_pred_train), (Y_test, Y_pred_test)
k_train, p_train = stats.shapiro(Y_train - Y_pred_train)
print('Train k = {0}, p = {1}'.format(k_train, p_train))

k_test, p_test = stats.shapiro(Y_test - Y_pred_test)
print('Test k = {0}, p = {1}'.format(k_test, p_test))
# Out:
# Train k = 0.9839723110198975, p = 0.036152251064777374
# Test k = 0.9668131470680237, p = 0.0042066811583936214

# %%
# Для полной выборки (Y, Y_pred) применим два статистических теста: shapiro и normaltest.
Y_pred = model.predict(X).flatten()

k_s, p_s = stats.shapiro(Y - Y_pred)
print('k_s = {0}, p_s = {1}'.format(k_s, p_s))

k_n, p_n = stats.normaltest(Y - Y_pred)
print('k_n = {0}, p_n = {1}'.format(k_n, p_n))
# Out:
# k_s = 0.981464147567749, p_s = 0.0005846547428518534
# k_n = 9.091472836131427, p_n = 0.01061235470821752

# %%
# И тоже самое визуально, с помощью грфиков квантиль-квантиль.
# Обучающая выборка
qqplot(Y_train - Y_pred_train)
plt.show()

# %%
# Тестовая выборка
qqplot(Y_test - Y_pred_test)
plt.show()

# %%
# Полная выборка
qqplot(Y - Y_pred)
plt.show()

# %%
plt.hist(Y - Y_pred, bins=50)
plt.show()

# %%
model.save('SimpleNeuralNetwork.h5')
