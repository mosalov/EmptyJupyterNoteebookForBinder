# %%
# Загрузка зависимостей
import numpy
import pandas
import matplotlib.pyplot as plt
import keras
from keras.models import Sequential
from keras.layers import Dense
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from scipy import stats
from statsmodels.graphics.gofplots import qqplot
# Out:
# Using TensorFlow backend.

# %%
# Загрузка подготовленного набора данных
dataset = pandas.read_csv('prepared_data.csv') # Убедиться в правильности пути к файлу!
dataset.head(10) # Вывод первых 10 строк
# Out:
#    Vendor_name      MYCT      MMIN      MMAX      CACH     CHMIN     CHMAX  \
# 0     0.000000  0.256630  0.251074  0.420445  1.000000  0.925513  1.000000
# 1     0.092516  0.045894  0.874463  1.000000  0.461880  0.694135  0.676123
# 2     0.092516  0.045894  0.874463  1.000000  0.461880  0.694135  0.676123
# 3     0.092516  0.045894  0.874463  1.000000  0.461880  0.694135  0.676123
# 4     0.092516  0.045894  0.874463  0.717236  0.461880  0.694135  0.478091
# 5     0.092516  0.035488  0.874463  1.000000  0.653197  0.694135  0.676123
# 6     0.092516  0.024463  1.000000  1.000000  0.653197  0.925513  0.676123
# 7     0.092516  0.024463  1.000000  1.000000  0.653197  0.925513  0.676123
# 8     0.092516  0.024463  1.000000  1.000000  0.653197  0.925513  0.676123
# 9     0.092516  0.024463  1.000000  1.000000  0.923760  1.000000  0.956183
#
#         PRP
# 0  1.229905
# 1  1.529143
# 2  1.332788
# 3  1.092443
# 4  0.833975
# 5  1.692548
# 6  1.832489
# 7  2.112740
# 8  2.312497
# 9  2.312497

# %%
# Выделение входных и выходных параметров:
# Выходной параметр - значение столбца обработанного набора данных, соответсвующее столбцу №8 из первоначального набора данных (machine.data.csv).
# Входные параметры - все остальные столбцы обработанного набора данных.
# Используем .values, чтобы индексы не попали в новые переменные и в дальнейшем не мешали нам, например, при построении графиков.
X = dataset.iloc[:, 0:7].values
Y = dataset['PRP'].values

# Обратите внимание на структуру вашего обработанного файлы и измените индексы, если нужно.

# %%
# Разделение данных на обучающую и тестовую выборки:
# Используем метод train_test_split библиотеки sklearn.
# Он разделяет заданные массивы входных и выходных параметров на две части каждый.
# Значение test_size определяет долю тестовой выборки в исходных данных.
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2)

# %%
# Задаем параметры структуры нейронной сети.

# Количество нейронов во входном слое должно быть равно количеству входных параметров.
input_layer_size = 7

# Количество нейронов в каждом скрытом слое и количество таких слоёв могут быть выбраны произвольно.
# Увеличение числа нейронов относительно предыдущего слоя позволяет лучше обрабатывать отдельные примеры.
# Уменьшение числа нейронов относительно предыдущего слоя позволяет обощать информацию и выводить новые правила.
# Увеличение числа слоёв помогает сети работать как более сложная функция.
first_hidden_layer_size = 50
second_hidden_layer_size = 50

# Количество нейронов в выходном слое должно быть равно количеству выходных параметров.
output_layer_size = 1

# Параметры обучения нейронной сети: количество эпох и размер батча.
epochs_number = 100
batch_size = 16

# %%
# Создание нейронной сети прямого распространения, пока она пустая, т.е. не содержит слоёв и нейронов.
model = Sequential()

# Входной слой и первый скрытый слой, функция активации - ReLU
model.add(Dense(first_hidden_layer_size, input_dim=input_layer_size, activation='relu'))

# Второй скрытый слой, функция активации - ReLU
model.add(Dense(second_hidden_layer_size, activation='relu'))

# Выходной слой, функция активации - линейная, т.к. решается задача регрессии.
model.add(Dense(output_layer_size, activation='linear'))

# %%
# Обзор нейронной сети, теперь в ней есть слои и нейроны.
# Если внимательно посмотреть на количество параметров, т.е. связей между нейронами, то можно увидеть, что автоматически добавлены нейроны смещения.
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 50)                400
# _________________________________________________________________
# dense_2 (Dense)              (None, 50)                2550
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 3,001
# Trainable params: 3,001
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Настройка нейронной сети.
# Функция потерь (loss) - среднеквадратическая ошибка.
# Оптимизатор (optimizer) - adam (в настоящий момент - это стандартный оптимизатор).
# Указываем метрики средняя абсолютная ошибка (mean_absolute_error) и среднеквадратическая ошиба (mean_squared_error) для дальнейшего анализа.
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error', 'mean_squared_error'])

# %%
# Обучение нейронной сети.
# На вход передаем обучающие и тестовые выборки, количество эпох и размер батча.
# На выходе получаем объект с историей обучения, который далее будем анализировать.
history = model.fit(X_train, Y_train, validation_data = (X_test,Y_test), epochs=epochs_number, batch_size=batch_size)
# Out:
# Train on 167 samples, validate on 42 samples
# Epoch 1/100
# 167/167 [==============================] - 0s 2ms/step - loss: 0.8687 - mean_absolute_error: 0.7476 - mean_squared_error: 0.8687 - val_loss: 0.8816 - val_mean_absolute_error: 0.7662 - val_mean_squared_error: 0.8816
# Epoch 2/100
# 167/167 [==============================] - 0s 277us/step - loss: 0.7027 - mean_absolute_error: 0.6788 - mean_squared_error: 0.7027 - val_loss: 0.6275 - val_mean_absolute_error: 0.6547 - val_mean_squared_error: 0.6275
# Epoch 3/100
# 167/167 [==============================] - 0s 474us/step - loss: 0.5520 - mean_absolute_error: 0.6017 - mean_squared_error: 0.5520 - val_loss: 0.4379 - val_mean_absolute_error: 0.5419 - val_mean_squared_error: 0.4379
# Epoch 4/100
# 167/167 [==============================] - 0s 459us/step - loss: 0.4113 - mean_absolute_error: 0.5154 - mean_squared_error: 0.4113 - val_loss: 0.2912 - val_mean_absolute_error: 0.4404 - val_mean_squared_error: 0.2912
# Epoch 5/100
# 167/167 [==============================] - 0s 224us/step - loss: 0.3147 - mean_absolute_error: 0.4419 - mean_squared_error: 0.3147 - val_loss: 0.2053 - val_mean_absolute_error: 0.3673 - val_mean_squared_error: 0.2053
# Epoch 6/100
# 167/167 [==============================] - 0s 242us/step - loss: 0.2564 - mean_absolute_error: 0.3982 - mean_squared_error: 0.2564 - val_loss: 0.1604 - val_mean_absolute_error: 0.3192 - val_mean_squared_error: 0.1604
# Epoch 7/100
# 167/167 [==============================] - 0s 565us/step - loss: 0.2292 - mean_absolute_error: 0.3797 - mean_squared_error: 0.2292 - val_loss: 0.1638 - val_mean_absolute_error: 0.3167 - val_mean_squared_error: 0.1638
# Epoch 8/100
# 167/167 [==============================] - 0s 465us/step - loss: 0.2158 - mean_absolute_error: 0.3725 - mean_squared_error: 0.2158 - val_loss: 0.1465 - val_mean_absolute_error: 0.2972 - val_mean_squared_error: 0.1465
# Epoch 9/100
# 167/167 [==============================] - 0s 263us/step - loss: 0.2077 - mean_absolute_error: 0.3584 - mean_squared_error: 0.2077 - val_loss: 0.1393 - val_mean_absolute_error: 0.2890 - val_mean_squared_error: 0.1393
# Epoch 10/100
# 167/167 [==============================] - 0s 392us/step - loss: 0.2030 - mean_absolute_error: 0.3608 - mean_squared_error: 0.2030 - val_loss: 0.1408 - val_mean_absolute_error: 0.2871 - val_mean_squared_error: 0.1408
# Epoch 11/100
# 167/167 [==============================] - 0s 453us/step - loss: 0.1920 - mean_absolute_error: 0.3494 - mean_squared_error: 0.1920 - val_loss: 0.1417 - val_mean_absolute_error: 0.2870 - val_mean_squared_error: 0.1417
# Epoch 12/100
# 167/167 [==============================] - 0s 150us/step - loss: 0.1905 - mean_absolute_error: 0.3483 - mean_squared_error: 0.1905 - val_loss: 0.1438 - val_mean_absolute_error: 0.2886 - val_mean_squared_error: 0.1438
# Epoch 13/100
# 167/167 [==============================] - 0s 342us/step - loss: 0.1875 - mean_absolute_error: 0.3501 - mean_squared_error: 0.1875 - val_loss: 0.1377 - val_mean_absolute_error: 0.2802 - val_mean_squared_error: 0.1377
# Epoch 14/100
# 167/167 [==============================] - 0s 148us/step - loss: 0.1815 - mean_absolute_error: 0.3351 - mean_squared_error: 0.1815 - val_loss: 0.1323 - val_mean_absolute_error: 0.2728 - val_mean_squared_error: 0.1323
# Epoch 15/100
# 167/167 [==============================] - 0s 438us/step - loss: 0.1798 - mean_absolute_error: 0.3399 - mean_squared_error: 0.1798 - val_loss: 0.1361 - val_mean_absolute_error: 0.2775 - val_mean_squared_error: 0.1361
# Epoch 16/100
# 167/167 [==============================] - ETA: 0s - loss: 0.0814 - mean_absolute_error: 0.2373 - mean_squared_error: 0.08 - 0s 166us/step - loss: 0.1842 - mean_absolute_error: 0.3363 - mean_squared_error: 0.1842 - val_loss: 0.1381 - val_mean_absolute_error: 0.2804 - val_mean_squared_error: 0.1381
# Epoch 17/100
# 167/167 [==============================] - 0s 377us/step - loss: 0.1757 - mean_absolute_error: 0.3356 - mean_squared_error: 0.1757 - val_loss: 0.1316 - val_mean_absolute_error: 0.2710 - val_mean_squared_error: 0.1316
# Epoch 18/100
# 167/167 [==============================] - 0s 178us/step - loss: 0.1721 - mean_absolute_error: 0.3313 - mean_squared_error: 0.1721 - val_loss: 0.1355 - val_mean_absolute_error: 0.2771 - val_mean_squared_error: 0.1355
# Epoch 19/100
# 167/167 [==============================] - 0s 437us/step - loss: 0.1723 - mean_absolute_error: 0.3241 - mean_squared_error: 0.1723 - val_loss: 0.1272 - val_mean_absolute_error: 0.2662 - val_mean_squared_error: 0.1272
# Epoch 20/100
# 167/167 [==============================] - 0s 144us/step - loss: 0.1670 - mean_absolute_error: 0.3267 - mean_squared_error: 0.1670 - val_loss: 0.1310 - val_mean_absolute_error: 0.2719 - val_mean_squared_error: 0.1310
# Epoch 21/100
# 167/167 [==============================] - 0s 403us/step - loss: 0.1658 - mean_absolute_error: 0.3248 - mean_squared_error: 0.1658 - val_loss: 0.1212 - val_mean_absolute_error: 0.2562 - val_mean_squared_error: 0.1212
# Epoch 22/100
# 167/167 [==============================] - 0s 163us/step - loss: 0.1664 - mean_absolute_error: 0.3211 - mean_squared_error: 0.1664 - val_loss: 0.1305 - val_mean_absolute_error: 0.2731 - val_mean_squared_error: 0.1305
# Epoch 23/100
# 167/167 [==============================] - 0s 482us/step - loss: 0.1620 - mean_absolute_error: 0.3218 - mean_squared_error: 0.1620 - val_loss: 0.1216 - val_mean_absolute_error: 0.2596 - val_mean_squared_error: 0.1216
# Epoch 24/100
# 167/167 [==============================] - 0s 162us/step - loss: 0.1615 - mean_absolute_error: 0.3187 - mean_squared_error: 0.1615 - val_loss: 0.1170 - val_mean_absolute_error: 0.2524 - val_mean_squared_error: 0.1170
# Epoch 25/100
# 167/167 [==============================] - 0s 380us/step - loss: 0.1624 - mean_absolute_error: 0.3156 - mean_squared_error: 0.1624 - val_loss: 0.1255 - val_mean_absolute_error: 0.2664 - val_mean_squared_error: 0.1255
# Epoch 26/100
# 167/167 [==============================] - 0s 153us/step - loss: 0.1557 - mean_absolute_error: 0.3115 - mean_squared_error: 0.1557 - val_loss: 0.1167 - val_mean_absolute_error: 0.2530 - val_mean_squared_error: 0.1167
# Epoch 27/100
# 167/167 [==============================] - 0s 408us/step - loss: 0.1545 - mean_absolute_error: 0.3083 - mean_squared_error: 0.1545 - val_loss: 0.1144 - val_mean_absolute_error: 0.2488 - val_mean_squared_error: 0.1144
# Epoch 28/100
# 167/167 [==============================] - 0s 161us/step - loss: 0.1533 - mean_absolute_error: 0.3127 - mean_squared_error: 0.1533 - val_loss: 0.1195 - val_mean_absolute_error: 0.2608 - val_mean_squared_error: 0.1195
# Epoch 29/100
# 167/167 [==============================] - 0s 382us/step - loss: 0.1516 - mean_absolute_error: 0.3074 - mean_squared_error: 0.1516 - val_loss: 0.1160 - val_mean_absolute_error: 0.2546 - val_mean_squared_error: 0.1160
# Epoch 30/100
# 167/167 [==============================] - 0s 157us/step - loss: 0.1493 - mean_absolute_error: 0.3050 - mean_squared_error: 0.1493 - val_loss: 0.1212 - val_mean_absolute_error: 0.2647 - val_mean_squared_error: 0.1212
# Epoch 31/100
# 167/167 [==============================] - 0s 214us/step - loss: 0.1517 - mean_absolute_error: 0.3061 - mean_squared_error: 0.1517 - val_loss: 0.1192 - val_mean_absolute_error: 0.2635 - val_mean_squared_error: 0.1192
# Epoch 32/100
# 167/167 [==============================] - 0s 149us/step - loss: 0.1514 - mean_absolute_error: 0.3139 - mean_squared_error: 0.1514 - val_loss: 0.1083 - val_mean_absolute_error: 0.2468 - val_mean_squared_error: 0.1083
# Epoch 33/100
# 167/167 [==============================] - 0s 358us/step - loss: 0.1491 - mean_absolute_error: 0.3027 - mean_squared_error: 0.1491 - val_loss: 0.1186 - val_mean_absolute_error: 0.2628 - val_mean_squared_error: 0.1186
# Epoch 34/100
# 167/167 [==============================] - 0s 167us/step - loss: 0.1431 - mean_absolute_error: 0.3018 - mean_squared_error: 0.1431 - val_loss: 0.1122 - val_mean_absolute_error: 0.2522 - val_mean_squared_error: 0.1122
# Epoch 35/100
# 167/167 [==============================] - 0s 257us/step - loss: 0.1413 - mean_absolute_error: 0.2956 - mean_squared_error: 0.1413 - val_loss: 0.1076 - val_mean_absolute_error: 0.2483 - val_mean_squared_error: 0.1076
# Epoch 36/100
# 167/167 [==============================] - 0s 374us/step - loss: 0.1452 - mean_absolute_error: 0.3031 - mean_squared_error: 0.1452 - val_loss: 0.1021 - val_mean_absolute_error: 0.2362 - val_mean_squared_error: 0.1021
# Epoch 37/100
# 167/167 [==============================] - 0s 161us/step - loss: 0.1398 - mean_absolute_error: 0.2961 - mean_squared_error: 0.1398 - val_loss: 0.1087 - val_mean_absolute_error: 0.2519 - val_mean_squared_error: 0.1087
# Epoch 38/100
# 167/167 [==============================] - 0s 144us/step - loss: 0.1349 - mean_absolute_error: 0.2890 - mean_squared_error: 0.1349 - val_loss: 0.1091 - val_mean_absolute_error: 0.2525 - val_mean_squared_error: 0.1091
# Epoch 39/100
# 167/167 [==============================] - 0s 374us/step - loss: 0.1338 - mean_absolute_error: 0.2874 - mean_squared_error: 0.1338 - val_loss: 0.1064 - val_mean_absolute_error: 0.2470 - val_mean_squared_error: 0.1064
# Epoch 40/100
# 167/167 [==============================] - 0s 169us/step - loss: 0.1331 - mean_absolute_error: 0.2872 - mean_squared_error: 0.1331 - val_loss: 0.1080 - val_mean_absolute_error: 0.2541 - val_mean_squared_error: 0.1080
# Epoch 41/100
# 167/167 [==============================] - 0s 411us/step - loss: 0.1312 - mean_absolute_error: 0.2863 - mean_squared_error: 0.1312 - val_loss: 0.1055 - val_mean_absolute_error: 0.2491 - val_mean_squared_error: 0.1055
# Epoch 42/100
# 167/167 [==============================] - 0s 152us/step - loss: 0.1298 - mean_absolute_error: 0.2836 - mean_squared_error: 0.1298 - val_loss: 0.0993 - val_mean_absolute_error: 0.2348 - val_mean_squared_error: 0.0993
# Epoch 43/100
# 167/167 [==============================] - 0s 203us/step - loss: 0.1303 - mean_absolute_error: 0.2824 - mean_squared_error: 0.1303 - val_loss: 0.1266 - val_mean_absolute_error: 0.2837 - val_mean_squared_error: 0.1266
# Epoch 44/100
# 167/167 [==============================] - 0s 153us/step - loss: 0.1305 - mean_absolute_error: 0.2849 - mean_squared_error: 0.1305 - val_loss: 0.0983 - val_mean_absolute_error: 0.2381 - val_mean_squared_error: 0.0983
# Epoch 45/100
# 167/167 [==============================] - 0s 383us/step - loss: 0.1257 - mean_absolute_error: 0.2799 - mean_squared_error: 0.1257 - val_loss: 0.1081 - val_mean_absolute_error: 0.2583 - val_mean_squared_error: 0.1081
# Epoch 46/100
# 167/167 [==============================] - 0s 143us/step - loss: 0.1289 - mean_absolute_error: 0.2833 - mean_squared_error: 0.1289 - val_loss: 0.1112 - val_mean_absolute_error: 0.2650 - val_mean_squared_error: 0.1112
# Epoch 47/100
# 167/167 [==============================] - 0s 393us/step - loss: 0.1305 - mean_absolute_error: 0.2846 - mean_squared_error: 0.1305 - val_loss: 0.0915 - val_mean_absolute_error: 0.2320 - val_mean_squared_error: 0.0915
# Epoch 48/100
# 167/167 [==============================] - 0s 181us/step - loss: 0.1213 - mean_absolute_error: 0.2737 - mean_squared_error: 0.1213 - val_loss: 0.1189 - val_mean_absolute_error: 0.2772 - val_mean_squared_error: 0.1189
# Epoch 49/100
# 167/167 [==============================] - 0s 386us/step - loss: 0.1393 - mean_absolute_error: 0.2964 - mean_squared_error: 0.1393 - val_loss: 0.0901 - val_mean_absolute_error: 0.2300 - val_mean_squared_error: 0.0901
# Epoch 50/100
# 167/167 [==============================] - 0s 154us/step - loss: 0.1352 - mean_absolute_error: 0.2917 - mean_squared_error: 0.1352 - val_loss: 0.1123 - val_mean_absolute_error: 0.2664 - val_mean_squared_error: 0.1123
# Epoch 51/100
# 167/167 [==============================] - 0s 442us/step - loss: 0.1203 - mean_absolute_error: 0.2717 - mean_squared_error: 0.1203 - val_loss: 0.0939 - val_mean_absolute_error: 0.2377 - val_mean_squared_error: 0.0939
# Epoch 52/100
# 167/167 [==============================] - 0s 412us/step - loss: 0.1180 - mean_absolute_error: 0.2711 - mean_squared_error: 0.1180 - val_loss: 0.0947 - val_mean_absolute_error: 0.2434 - val_mean_squared_error: 0.0947
# Epoch 53/100
# 167/167 [==============================] - 0s 149us/step - loss: 0.1180 - mean_absolute_error: 0.2706 - mean_squared_error: 0.1180 - val_loss: 0.0936 - val_mean_absolute_error: 0.2409 - val_mean_squared_error: 0.0936
# Epoch 54/100
# 167/167 [==============================] - 0s 135us/step - loss: 0.1251 - mean_absolute_error: 0.2789 - mean_squared_error: 0.1251 - val_loss: 0.1046 - val_mean_absolute_error: 0.2592 - val_mean_squared_error: 0.1046
# Epoch 55/100
# 167/167 [==============================] - 0s 412us/step - loss: 0.1192 - mean_absolute_error: 0.2730 - mean_squared_error: 0.1192 - val_loss: 0.0879 - val_mean_absolute_error: 0.2244 - val_mean_squared_error: 0.0879
# Epoch 56/100
# 167/167 [==============================] - 0s 150us/step - loss: 0.1200 - mean_absolute_error: 0.2775 - mean_squared_error: 0.1200 - val_loss: 0.1219 - val_mean_absolute_error: 0.2831 - val_mean_squared_error: 0.1219
# Epoch 57/100
# 167/167 [==============================] - 0s 193us/step - loss: 0.1146 - mean_absolute_error: 0.2670 - mean_squared_error: 0.1146 - val_loss: 0.0861 - val_mean_absolute_error: 0.2249 - val_mean_squared_error: 0.0861
# Epoch 58/100
# 167/167 [==============================] - 0s 134us/step - loss: 0.1214 - mean_absolute_error: 0.2754 - mean_squared_error: 0.1214 - val_loss: 0.0970 - val_mean_absolute_error: 0.2509 - val_mean_squared_error: 0.0970
# Epoch 59/100
# 167/167 [==============================] - 0s 181us/step - loss: 0.1125 - mean_absolute_error: 0.2645 - mean_squared_error: 0.1125 - val_loss: 0.0918 - val_mean_absolute_error: 0.2422 - val_mean_squared_error: 0.0918
# Epoch 60/100
# 167/167 [==============================] - 0s 147us/step - loss: 0.1119 - mean_absolute_error: 0.2627 - mean_squared_error: 0.1119 - val_loss: 0.0900 - val_mean_absolute_error: 0.2396 - val_mean_squared_error: 0.0900
# Epoch 61/100
# 167/167 [==============================] - 0s 381us/step - loss: 0.1088 - mean_absolute_error: 0.2581 - mean_squared_error: 0.1088 - val_loss: 0.0964 - val_mean_absolute_error: 0.2493 - val_mean_squared_error: 0.0964
# Epoch 62/100
# 167/167 [==============================] - 0s 155us/step - loss: 0.1076 - mean_absolute_error: 0.2577 - mean_squared_error: 0.1076 - val_loss: 0.0881 - val_mean_absolute_error: 0.2383 - val_mean_squared_error: 0.0881
# Epoch 63/100
# 167/167 [==============================] - 0s 384us/step - loss: 0.1078 - mean_absolute_error: 0.2602 - mean_squared_error: 0.1078 - val_loss: 0.0880 - val_mean_absolute_error: 0.2360 - val_mean_squared_error: 0.0880
# Epoch 64/100
# 167/167 [==============================] - 0s 137us/step - loss: 0.1069 - mean_absolute_error: 0.2585 - mean_squared_error: 0.1069 - val_loss: 0.0926 - val_mean_absolute_error: 0.2467 - val_mean_squared_error: 0.0926
# Epoch 65/100
# 167/167 [==============================] - 0s 426us/step - loss: 0.1084 - mean_absolute_error: 0.2572 - mean_squared_error: 0.1084 - val_loss: 0.0931 - val_mean_absolute_error: 0.2469 - val_mean_squared_error: 0.0931
# Epoch 66/100
# 167/167 [==============================] - 0s 152us/step - loss: 0.1035 - mean_absolute_error: 0.2547 - mean_squared_error: 0.1035 - val_loss: 0.0879 - val_mean_absolute_error: 0.2401 - val_mean_squared_error: 0.0879
# Epoch 67/100
# 167/167 [==============================] - 0s 432us/step - loss: 0.1044 - mean_absolute_error: 0.2536 - mean_squared_error: 0.1044 - val_loss: 0.0853 - val_mean_absolute_error: 0.2313 - val_mean_squared_error: 0.0853
# Epoch 68/100
# 167/167 [==============================] - 0s 151us/step - loss: 0.1028 - mean_absolute_error: 0.2529 - mean_squared_error: 0.1028 - val_loss: 0.0914 - val_mean_absolute_error: 0.2442 - val_mean_squared_error: 0.0914
# Epoch 69/100
# 167/167 [==============================] - 0s 448us/step - loss: 0.1008 - mean_absolute_error: 0.2492 - mean_squared_error: 0.1008 - val_loss: 0.0834 - val_mean_absolute_error: 0.2316 - val_mean_squared_error: 0.0834
# Epoch 70/100
# 167/167 [==============================] - 0s 142us/step - loss: 0.1004 - mean_absolute_error: 0.2502 - mean_squared_error: 0.1004 - val_loss: 0.0880 - val_mean_absolute_error: 0.2401 - val_mean_squared_error: 0.0880
# Epoch 71/100
# 167/167 [==============================] - 0s 332us/step - loss: 0.0992 - mean_absolute_error: 0.2504 - mean_squared_error: 0.0992 - val_loss: 0.0877 - val_mean_absolute_error: 0.2378 - val_mean_squared_error: 0.0877
# Epoch 72/100
# 167/167 [==============================] - 0s 158us/step - loss: 0.1037 - mean_absolute_error: 0.2561 - mean_squared_error: 0.1037 - val_loss: 0.0817 - val_mean_absolute_error: 0.2266 - val_mean_squared_error: 0.0817
# Epoch 73/100
# 167/167 [==============================] - 0s 410us/step - loss: 0.1031 - mean_absolute_error: 0.2537 - mean_squared_error: 0.1031 - val_loss: 0.1017 - val_mean_absolute_error: 0.2584 - val_mean_squared_error: 0.1017
# Epoch 74/100
# 167/167 [==============================] - 0s 175us/step - loss: 0.1020 - mean_absolute_error: 0.2511 - mean_squared_error: 0.1020 - val_loss: 0.0849 - val_mean_absolute_error: 0.2320 - val_mean_squared_error: 0.0849
# Epoch 75/100
# 167/167 [==============================] - 0s 408us/step - loss: 0.0965 - mean_absolute_error: 0.2449 - mean_squared_error: 0.0965 - val_loss: 0.0843 - val_mean_absolute_error: 0.2326 - val_mean_squared_error: 0.0843
# Epoch 76/100
# 167/167 [==============================] - 0s 182us/step - loss: 0.0960 - mean_absolute_error: 0.2437 - mean_squared_error: 0.0960 - val_loss: 0.0893 - val_mean_absolute_error: 0.2421 - val_mean_squared_error: 0.0893
# Epoch 77/100
# 167/167 [==============================] - 0s 397us/step - loss: 0.0943 - mean_absolute_error: 0.2408 - mean_squared_error: 0.0943 - val_loss: 0.0876 - val_mean_absolute_error: 0.2371 - val_mean_squared_error: 0.0876
# Epoch 78/100
# 167/167 [==============================] - 0s 148us/step - loss: 0.0958 - mean_absolute_error: 0.2435 - mean_squared_error: 0.0958 - val_loss: 0.0890 - val_mean_absolute_error: 0.2408 - val_mean_squared_error: 0.0890
# Epoch 79/100
# 167/167 [==============================] - 0s 438us/step - loss: 0.0958 - mean_absolute_error: 0.2454 - mean_squared_error: 0.0958 - val_loss: 0.0819 - val_mean_absolute_error: 0.2322 - val_mean_squared_error: 0.0819
# Epoch 80/100
# 167/167 [==============================] - 0s 149us/step - loss: 0.0922 - mean_absolute_error: 0.2412 - mean_squared_error: 0.0922 - val_loss: 0.0854 - val_mean_absolute_error: 0.2330 - val_mean_squared_error: 0.0854
# Epoch 81/100
# 167/167 [==============================] - 0s 407us/step - loss: 0.0941 - mean_absolute_error: 0.2422 - mean_squared_error: 0.0941 - val_loss: 0.0879 - val_mean_absolute_error: 0.2408 - val_mean_squared_error: 0.0879
# Epoch 82/100
# 167/167 [==============================] - 0s 142us/step - loss: 0.0897 - mean_absolute_error: 0.2388 - mean_squared_error: 0.0897 - val_loss: 0.0813 - val_mean_absolute_error: 0.2302 - val_mean_squared_error: 0.0813
# Epoch 83/100
# 167/167 [==============================] - 0s 415us/step - loss: 0.0934 - mean_absolute_error: 0.2397 - mean_squared_error: 0.0934 - val_loss: 0.0828 - val_mean_absolute_error: 0.2317 - val_mean_squared_error: 0.0828
# Epoch 84/100
# 167/167 [==============================] - 0s 151us/step - loss: 0.0892 - mean_absolute_error: 0.2365 - mean_squared_error: 0.0892 - val_loss: 0.0864 - val_mean_absolute_error: 0.2363 - val_mean_squared_error: 0.0864
# Epoch 85/100
# 167/167 [==============================] - 0s 177us/step - loss: 0.0899 - mean_absolute_error: 0.2338 - mean_squared_error: 0.0899 - val_loss: 0.0840 - val_mean_absolute_error: 0.2330 - val_mean_squared_error: 0.0840
# Epoch 86/100
# 167/167 [==============================] - 0s 124us/step - loss: 0.0886 - mean_absolute_error: 0.2334 - mean_squared_error: 0.0886 - val_loss: 0.0804 - val_mean_absolute_error: 0.2301 - val_mean_squared_error: 0.0804
# Epoch 87/100
# 167/167 [==============================] - 0s 451us/step - loss: 0.0985 - mean_absolute_error: 0.2542 - mean_squared_error: 0.0985 - val_loss: 0.1225 - val_mean_absolute_error: 0.2792 - val_mean_squared_error: 0.1225
# Epoch 88/100
# 167/167 [==============================] - 0s 135us/step - loss: 0.1037 - mean_absolute_error: 0.2584 - mean_squared_error: 0.1037 - val_loss: 0.0821 - val_mean_absolute_error: 0.2320 - val_mean_squared_error: 0.0821
# Epoch 89/100
# 167/167 [==============================] - 0s 384us/step - loss: 0.0898 - mean_absolute_error: 0.2355 - mean_squared_error: 0.0898 - val_loss: 0.0792 - val_mean_absolute_error: 0.2299 - val_mean_squared_error: 0.0792
# Epoch 90/100
# 167/167 [==============================] - 0s 151us/step - loss: 0.0867 - mean_absolute_error: 0.2327 - mean_squared_error: 0.0867 - val_loss: 0.0864 - val_mean_absolute_error: 0.2357 - val_mean_squared_error: 0.0864
# Epoch 91/100
# 167/167 [==============================] - 0s 395us/step - loss: 0.0862 - mean_absolute_error: 0.2292 - mean_squared_error: 0.0862 - val_loss: 0.0847 - val_mean_absolute_error: 0.2349 - val_mean_squared_error: 0.0847
# Epoch 92/100
# 167/167 [==============================] - 0s 163us/step - loss: 0.0877 - mean_absolute_error: 0.2325 - mean_squared_error: 0.0877 - val_loss: 0.0806 - val_mean_absolute_error: 0.2291 - val_mean_squared_error: 0.0806
# Epoch 93/100
# 167/167 [==============================] - 0s 377us/step - loss: 0.0856 - mean_absolute_error: 0.2285 - mean_squared_error: 0.0856 - val_loss: 0.0856 - val_mean_absolute_error: 0.2361 - val_mean_squared_error: 0.0856
# Epoch 94/100
# 167/167 [==============================] - 0s 151us/step - loss: 0.0841 - mean_absolute_error: 0.2280 - mean_squared_error: 0.0841 - val_loss: 0.0803 - val_mean_absolute_error: 0.2305 - val_mean_squared_error: 0.0803
# Epoch 95/100
# 167/167 [==============================] - 0s 381us/step - loss: 0.0860 - mean_absolute_error: 0.2309 - mean_squared_error: 0.0860 - val_loss: 0.0837 - val_mean_absolute_error: 0.2345 - val_mean_squared_error: 0.0837
# Epoch 96/100
# 167/167 [==============================] - 0s 142us/step - loss: 0.0858 - mean_absolute_error: 0.2332 - mean_squared_error: 0.0858 - val_loss: 0.0919 - val_mean_absolute_error: 0.2411 - val_mean_squared_error: 0.0919
# Epoch 97/100
# 167/167 [==============================] - 0s 457us/step - loss: 0.0830 - mean_absolute_error: 0.2257 - mean_squared_error: 0.0830 - val_loss: 0.0797 - val_mean_absolute_error: 0.2290 - val_mean_squared_error: 0.0797
# Epoch 98/100
# 167/167 [==============================] - 0s 139us/step - loss: 0.0820 - mean_absolute_error: 0.2261 - mean_squared_error: 0.0820 - val_loss: 0.0832 - val_mean_absolute_error: 0.2329 - val_mean_squared_error: 0.0832
# Epoch 99/100
# 167/167 [==============================] - 0s 360us/step - loss: 0.0817 - mean_absolute_error: 0.2235 - mean_squared_error: 0.0817 - val_loss: 0.0879 - val_mean_absolute_error: 0.2366 - val_mean_squared_error: 0.0879
# Epoch 100/100
# 167/167 [==============================] - 0s 142us/step - loss: 0.0810 - mean_absolute_error: 0.2237 - mean_squared_error: 0.0810 - val_loss: 0.0820 - val_mean_absolute_error: 0.2297 - val_mean_squared_error: 0.0820

# %%
# Выводим динамику среднего абсолютного отклонения от номера эпохи обучения.
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error']) 
plt.title('Model MAE') 
plt.ylabel('MAE') 
plt.xlabel('Epoch') 
plt.legend(['Train', 'Test'], loc='upper right') 
plt.show()

# %%
# Выводим динамику среднеквадратического отклонения, т.е. значения функции потерь, от номера эпохи обучения.
# Видно, что в процессе обучения сеть с каждой эпохой вычисляет всё более точные прогнозы значений Y.
plt.plot(history.history['mean_squared_error'])
plt.plot(history.history['val_mean_squared_error']) 
plt.title('Model MSE') 
plt.ylabel('MSE') 
plt.xlabel('Epoch') 
plt.legend(['Train', 'Test'], loc='upper right') 
plt.show()

# %%
# Предсказание уже обученной нейронной сети на обучающей выборке:
Y_pred_train = model.predict(X_train).flatten()

# %%
# Сравним эталонные значения Y_train и результат работы обученной нейронной сети Y_pred_train для обучающей выборки.
# В идеальной ситуации они должны совпадать, т.е. точки (Y_train[i], Y_pred_train[i]) должны лежать на прямой Y_train = Y_pred_train.
plt.plot(Y_train, Y_pred_train, 'bo')
plt.plot([-2,2], [-2,2], 'r-')
plt.title('Test vs Pred_test') 
plt.ylabel('Pred_test') 
plt.xlabel('Test') 
plt.show()

# %%
# Выведем сами значения Y_train и Y_pred_train.
plt.plot(Y_train)
plt.plot(Y_pred_train)
plt.show()

# %%
# Таким образом, обучение по обучающей выборке проведено.
# Теперь проверим работу нейроной сети на тестовой выборке.

# Предсказание обученной нейронной сети на тестовой выборке:
Y_pred_test = model.predict(X_test).flatten()

# %%
# Сравним эталонные значения Y_test и результат работы обученной нейронной сети Y_pred_test для тестовой выборки.
plt.plot(Y_test, Y_pred_test, 'bo')
plt.plot([-2,2], [-2,2], 'r-')
plt.title('Test vs Pred_test') 
plt.ylabel('Pred_test') 
plt.xlabel('Test') 
plt.show()

# %%
# Выведем сами значения Y_test и Y_pred_test.
plt.plot(Y_test)
plt.plot(Y_pred_test)
plt.show()

# %%
# Итого, качество работы нейронной сети на тестовых данных ниже, чем на обучающих - это ожидаемо.
# Тем не менее, нейронная сеть способна найти зависимости и предсказвать значение Y по X с приемлемым уровенм точности.

# Сравним среднеквадратичные ошибки (значения функции потерь) для обучающей и тестовой выборок.
print(numpy.sqrt(mean_squared_error(Y_train, Y_pred_train)))
print(numpy.sqrt(mean_squared_error(Y_test, Y_pred_test)))
# Out:
# 0.2794141542663836
# 0.2863556250207837

# %%
# Проверим на нормальное распределение разности пар (Y_train, Y_pred_train), (Y_test, Y_pred_test)
# Для этого используем библиотеку scipy и метод stats.shapiro.
k_train, p_train = stats.shapiro(Y_train - Y_pred_train)
print('Train k = {0}, p = {1}'.format(k_train, p_train))

k_test, p_test = stats.shapiro(Y_test - Y_pred_test)
print('Test k = {0}, p = {1}'.format(k_test, p_test))
# Out:
# Train k = 0.9942558407783508, p = 0.7605748176574707
# Test k = 0.9881979823112488, p = 0.9369703531265259

# %%
# Для полной выборки (Y, Y_pred) применим два статистических теста: shapiro и normaltest.
Y_pred = model.predict(X).flatten()

k_s, p_s = stats.shapiro(Y - Y_pred)
print('k_s = {0}, p_s = {1}'.format(k_s, p_s))

k_n, p_n = stats.normaltest(Y - Y_pred)
print('k_n = {0}, p_n = {1}'.format(k_n, p_n))
# Out:
# k_s = 0.9952820539474487, p_s = 0.7646589279174805
# k_n = 0.9722143391883066, p_n = 0.6150158927779479

# %%
# И тоже самое визуально, с помощью грфиков квантиль-квантиль.
# Обучающая выборка
qqplot(Y_train - Y_pred_train)
plt.show()

# %%
# Тестовая выборка
qqplot(Y_test - Y_pred_test)
plt.show()

# %%
# Полная выборка
qqplot(Y - Y_pred)
plt.show()

# %%
# Можо также визульно убедиться, что распределения "почти нормальное".
plt.hist(Y - Y_pred, bins=50)
plt.show()

# %%
# Сохраним обученную нейронную сеть, название файла можно выбрать любое, расширение - h5.
model.save('SimpleNeuralNetwork.h5')
